# %%
# TODO

# < 1h
# Make basic version with no nlp

# Clean code, rearrange in clear steps : panda join, slipt, preprocessing, training
# clean Variable names (make sure it still works), add comments


# ~1h
# make the diy nlp with most occuring degree terms
# test if imporvements



# pandas output
#email to ask 

# test rnn

# improvements: cross check with friend list

# %%
import os
import urllib.request
import pandas as pd

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# Downloading the data, so that we don't have to do it again if we restart the kernel

# %%
urls=["https://info0.s3.us-east-2.amazonaws.com/recruitment/positions.csv","https://info0.s3.us-east-2.amazonaws.com/recruitment/education.csv","https://info0.s3.us-east-2.amazonaws.com/recruitment/jobtitle_seniority.csv"]

# data folder, create if it does not exists
os.makedirs('./data/', exist_ok=True) 
    
# if .csv file does not exists, download it
for url in urls:
    path='./data/' + os.path.basename(url)
    if not os.path.exists(path):
        urllib.request.urlretrieve(url, path)
        
print('data downloaded')
# Out:
# data downloaded

# %% [markdown]
# Loading the data into pandas data frames

# %%
#TODO dl?
#TODO S3 bucket code?
df_positions = pd.read_csv("./data/positions.csv")
df_education = pd.read_csv("./data/education.csv")
df_seniority = pd.read_csv("./data/jobtitle_seniority.csv")

# %% [markdown]
# # 1. Checking the data

# %% [markdown]
# ## 1.1 Individual data frames

# %%
df_positions=df_positions.sort_values(by=['user_id'])
df_positions.tail(10)
# Out:
#                                                   user_id  \
# 162425  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 15089   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 146169  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 15923   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 20486   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 309939  zzrNxfUzwZXNkSs15haLyA4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 338504  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 334912  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 359048  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 248375  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
#
#                                                  jobtitle   startdate  \
# 162425                     student_senior_service_college  2012-08-01
# 15089                       command_general_staff_college  2004-07-01
# 146169             engineer_company_brigade_staff_trainer  2002-04-01
# 15923                            student_engineer_officer  1998-01-01
# 20486     company_commander_battalion_battalion_assistant  1998-11-01
# 309939  partner_head_private_client_department_|_law_p...  1992-01-01
# 338504                  coordinador_de_personal_embarcado  2017-12-01
# 334912                  operador_|_logistics_supply_chain  2014-11-01
# 359048                  supervisor_de_personal_|_maritime  2016-05-01
# 248375    supervisor_de_personal_|_logistics_supply_chain  2015-11-01
#
#            enddate
# 162425  2013-06-01
# 15089   2005-06-01
# 146169  2004-06-01
# 15923   1998-10-01
# 20486   2002-03-01
# 309939         NaN
# 338504         NaN
# 334912  2015-09-01
# 359048  2017-09-01
# 248375  2016-05-01

# %% [markdown]
# #### Looking at the dates, linkedIn only has the year and month information, so date formatting is YYYY-MM-DD
# #### Position titles and fields are seperated by '\_|\_', words are seperated by '_'

# %%
df_education=df_education.sort_values(by=['user_id'])
df_education.head()
# Out:
#                                                   user_id  \
# 99508   ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92083   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92505   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 133238  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
# 5126    ++6zEVtPCi83vpPTHSY2Vg5+2cvffV/mNepQVJd0smgtpB...
#
#                                    major   startdate     enddate
# 99508                                 BS  1949-01-01  1953-01-01
# 92083                  BS in Electronics  1973-01-01  1978-01-01
# 92505                                NaN  1984-01-01  1987-01-01
# 133238               Master Grande Ecole  2013-01-01  2016-01-01
# 5126    Bachelor of Science (B.Sc.) (ED)  2001-01-01  2006-01-01

# %%
df_seniority=df_seniority.sort_values(by=['user_id'])
df_seniority.head()
# Out:
#                                                   user_id  \
# 90141   ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 71129   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 222292  ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 399946  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
# 220871  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
#
#                                                  jobtitle  seniority
# 90141                   former_owner_presently_consultant   7.064817
# 71129   design_engineer_|_mechanical_industrial_engine...   3.331507
# 222292                  owner_|_computer_network_security   7.334247
# 399946  digital_communication_social_medias_activation...   4.307247
# 220871                    event_promoter_public_relations   1.908356

# %%
print(df_education.info())
print(df_positions.info())
print(df_seniority.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226184 entries, 99508 to 169422
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    226184 non-null  object
#  1   major      162346 non-null  object
#  2   startdate  197556 non-null  object
#  3   enddate    190658 non-null  object
# dtypes: object(4)
# memory usage: 8.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377585 entries, 41525 to 248375
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    377585 non-null  object
#  1   jobtitle   376136 non-null  object
#  2   startdate  368526 non-null  object
#  3   enddate    270354 non-null  object
# dtypes: object(4)
# memory usage: 14.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416295 entries, 90141 to 126315
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    416295 non-null  object
#  1   jobtitle   414290 non-null  object
#  2   seniority  416295 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 12.7+ MB
# None

# %%
# give the number of DISTINCT users
def count_users(df):
    return len(pd.unique(df['user_id']))

# %% [markdown]
# #### As expected a person can have multiple education, and position entries

# %%
test_id =df_education.iat[2,0]
def get_user_history(user_id):
    print(df_education[df_education['user_id'].str.contains(user_id,regex=False,na=False)][['major', 'startdate','enddate']])
    print(df_positions[df_positions['user_id'].str.contains(user_id,regex=False,na=False)][['jobtitle', 'startdate','enddate']])
    print(df_seniority[df_seniority['user_id'].str.contains(user_id,regex=False,na=False)][['jobtitle', 'seniority']])
get_user_history(test_id)
# Out:
#                    major   startdate     enddate
# 92083  BS in Electronics  1973-01-01  1978-01-01
# 92505                NaN  1984-01-01  1987-01-01
#                                                  jobtitle   startdate  \
# 9781                    owner_|_computer_network_security  1993-06-01
# 106525  design_engineer_|_mechanical_industrial_engine...  1984-10-01
#
#            enddate
# 9781           NaN
# 106525  1989-05-01
#                                                  jobtitle  seniority
# 71129   design_engineer_|_mechanical_industrial_engine...   3.331507
# 222292                  owner_|_computer_network_security   7.334247

# %% [markdown]
# ## 1.2 Missing values

# %% [markdown]
# #### Missing values for each df
# There are more missing values for end dates because it can the current position / education program of someone
#
# Missing values for dates are more important than for education/jobtittles to predict the age

# %%
#Missing values
print(df_positions.isna().sum(),'------',sep='\n')
print(df_education.isna().sum(),'------',sep='\n')
print(df_seniority.isna().sum(),'------',sep='\n')
# Out:
# user_id           0
# jobtitle       1449
# startdate      9059
# enddate      107231
# dtype: int64
# ------
# user_id          0
# major        63838
# startdate    28628
# enddate      35526
# dtype: int64
# ------
# user_id         0
# jobtitle     2005
# seniority       0
# dtype: int64
# ------

# %% [markdown]
# #### Missing starting dates AND enddates are problematic because it makes it hard to impute data

# %%
df_missing_pos=df_positions[df_positions['enddate'].isna() & df_positions['startdate'].isna()]
df_missing_sen=df_seniority[df_seniority['seniority'].isna() ]
df_missing_edu=df_education[df_education['enddate'].isna() & df_education['startdate'].isna()]
print(count_users(df_missing_pos),'unique users missing job date info in df_positions')
print(count_users(df_missing_sen),'unique users missing seniority info')
print(count_users(df_missing_edu),'unique users missing education date info')
# Out:
# 6518 unique users missing job date info in df_positions
# 0 unique users missing seniority info
# 18036 unique users missing education date info

# %% [markdown]
# #### This is even more true if there are no dates for both the education and job entries

# %%
df_missing_all=df_missing_pos.merge(df_missing_edu, how='inner',left_on=['user_id'], right_on=['user_id'])
print(count_users(df_missing_all),'unique users missing dates on all education and job info')
# Out:
# 981 unique users missing dates on all education and job info

# %% [markdown]
# # 2. Splitting the data to get training data
#
# ## dataprocessing will be done after to prevent data leakage

# %% [markdown]
# ## 2.1 Choosing the training Data
#
# People with highscool information have ages that are easy to predict since most people end highschool at the same age.
# The same is true for Bachelors.
# As a general rule, the ealier the education is in terms of degree, the better it is to predict the age because of the smaller variability.
#
# Because there are more people with bachelor information (1/3 of the data) we will use the starting date of the bachelor to determine someone's age for the training data

# %%
mask_high = df_education.major.apply(lambda x: ('highschool' in str(x).lower()) or ('high school' in str(x).lower()) )
print(count_users(df_education[mask_high]),'unique users with a highschool info')
# Out:
# 3368 unique users with a highschool info

# %%
bachelors=['bachelor','bs ','ba ','b.s.','b.a.']
mask_ba = df_education.major.apply(lambda x:  any(bachelor in str(x).lower() for bachelor in bachelors))
print(count_users(df_education[mask_ba]),'unique users with a bachelor info')
# Out:
# 37463 unique users with a bachelor info

# %%
bachelors=['bachelor']
mask_ba = df_education.major.apply(lambda x:  any(bachelor in str(x).lower() for bachelor in bachelors))
print(count_users(df_education[mask_ba]),'unique users with a bachelor info containing exactly \'bachelor\'')
# Out:
# 33931 unique users with a bachelor info containing exactly 'bachelor'

# %% [markdown]
# #### We will use the later as it is simpler to work with, and 1/3 of the data as training data is enough.
# ##### In the more advanced versions, we use NLP and clustering to encode similer majors, taking into account abbreviations.

# %%
training_users=pd.unique(df_education[mask_ba]['user_id']).tolist()

# %%
training_users
# Out:
# ['++6zEVtPCi83vpPTHSY2Vg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++8qqHNDQSyp1Yd45ROBZg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++P3GpkLINRrbYEiFplujg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++QrpNyfgK5vmh9A9q+J9Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++SC6Oywfs2GDplzAWlNIw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++Upv8fhNd5eyDVjpW6xKA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++aDwTD/+43NOn2//vSmTA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++ezojV5y6oN+zgZrWd8Rw+/8VEIFuQmbQ/jHgHWG0kf/bHrn17MPg==',
#  '++i6HnDhaBuEbzXQYQz+nw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '++rH2ZxLmNrpCF9UEcWcAmEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+/1ZQ3gBdWzYLeCLG54vvg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+/1ljTXFqTnMbl2zjBrcbQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+/BtP+2ipMNHSC5ejp4ggg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+/SqUKTcKxMgKoSRAHhC7w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+/bzU/BUXuqA2cR+P3JoHQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+/kCokrn4FkHYC/GvHLv/w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+02gInNMb8KUKcP5UL7dCQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0Hqf0uBmhMn0bb4nCA4vA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0KqWAYNbUhy0vfklZhhdHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+0Tt6rmm+fU7MmvucIQRyQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+0fdWsjpFPieIxotiRUs2w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0hHeNacM06zq4RtLfGQng5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0lc+1zBAXhR3UZHSTfrp3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+0oqZ8NFwMvxKbe9Oc2aKg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0wE1HPCsCPf3VUqX1CYIg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+0zv4P29fTAskVm0DAKBFw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+1Juuc1yrFduBWuoRXERIXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+1eREbqW3AkXDMuCqnzFfw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+1eprd4v4bzgMSaljFmRiA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+1iuHYyutnSdz6hG6nEfeQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+1s1hNi2M1VGvc1pAAUU+3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+1yunDuU9dHCPT1VZ0drjQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+2/SL+q7SoM59X//kEocMg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+240TiCYDI18OUkD83QiRw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+2hPCrXDM2n12yLeucTBFg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+2hbUBUUr4Zvm3f1hNnj2w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+2hoK5WZx73NUBw+SGEGPw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+2rsoIIbAlrmQH4joQ5EMw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+34zlMEapB7f27fpEpXgWA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+36K2BGfF+Zd4wXZMTlr3w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+3BhG4deFLYrA97mMiJvQg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+3E2ryBexh8x2B/OL93Dau0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '+3KpAMFw+JBAM+8rWriWzw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+3VSSjl5R3fn6YMUMNnSTQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+3WU5wm0MgLjPKJ7YXIurg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+3YjnuIdBToA6FC5gHzY1nAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+413F4T03A7Vk5c+WzZWnA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+4771Y2qKxIQ47I5vHOb5Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+48uYGjA6zL8wz9CtYhdKw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+4B2B3LLC2sBjjyUqCz74w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+4cxPw2auZFTbv2JEImjfLE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '+4gnFGF3m+B2phf5HcyfLg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+4w8jJsRgd7ECwl5N1Pb9Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+5UuhKYDqGSxCifjlR4f0g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+5oRYHdb8Jjnshg/EOI1RQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+6D3+oNzUCLpgMtCj9mlTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+6X3GSciuesEvzjDvtCpQg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+6fsk7vR0XmpkFSt6cf6GQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+6krNJZgyXnjcUw0NT22uA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+6v/qtjEVHQ/jc0bnpTI4Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+70DA/Z4uDiOmsOT2woxJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+75w7TSqqHzCxFzS1lI2Wg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+7VJ24/g88q4XswRxYst6Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+7VK3KotvB12wtDiOFqKaQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+7XvjX/OkIw/6zZq7gtUiO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '+7haG/+RczHm2frLL8z0cg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+7s0y7louRySna8rapqpvg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+7viLxQWwvJDUnMUPF/fBg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8/emsOGDg32O0js2jkvrw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+837CXEygJ1dAeagrDNS4A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+85u2Wyyt8qTAvMc5axToQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+87YSUGF9hm2JTzpiWvJjw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8AlTtuIN4OWfjFOsARaxw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+8Fo6qTJt5a8nz7rNkDo1GEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+8KUqdap7siSfJP5DQmX1g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8LaPNQQRXJbf6bZfKwM5Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+8T2QNRCNwWHoN1z54s+Ig4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+8XruB9Si7aXCa8V3/vlWA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8erweCNr+vovVekf2sEGXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+8jI2kb+nNm9xJnwWoLsqg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8sMzuNd/S334M1MtHnnwg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+8tt8okaCDmUzsQWsMoivw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9+iATQV5WJS3gEZBpmKyA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+97SNSOfebIuK55nZ/Pg1g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9Baqy28bFvLNJZqqHPP7r4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '+9Q0RQRr1TooRghuiCwbmQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9T7JPPaVQJpaY7Bw5HftQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9ZtiY0WJ1/SRUc2qe9BgA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+9hEc4qCcQiI/F+jJnbLfQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9i9v/+cZo839llu+FQe2A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9mVESQH/byqC0/46hSt+Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9uePpJm4KoL1RK4+zJ/kg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+9w9cSUReWgX5Ei5u8eVDw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+A26TmK27T9btwDe7eX50Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+A8CsF+L5GY7ap7M1K5IPzr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+AM0S5gprAhph6hei5tOiA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+ARe3TsZWKeA9+kCQV57Mg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AURwYkyDFkyTFpPvUUOdQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AW1OBfTCiL/RlDX34buGA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AfQFkJhetxPACdUkKw9vg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AoAEnX/CW/CpU8I4P76yA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Ap5g21IOIuWFJsvqiiyGQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AtHffnVt9GRbOZRYN4ePg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+AxD+ffYS2PPdSv70qRq0A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Axn5/H7u9lrpfrCh7vfJPtw1eRGwPAVbQ/jHgHWG0kf/bHrn17MPg==',
#  '+BFyoVQJPYRYfY1jKiK45Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+BHH+SfMY2l6j/TtQBvTrQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+BPaF73pNydoW2CAbQJ2JQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+BSNAXhOg3qXhHGSL83xTg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+BV+bm6nmB6yga0LAQGAxQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+BdA37z//lxL59fljjiyfg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Bn9kEVQCIYf8+8XlOMBNw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Bs/0Vscn+USYOII530jSQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ByzsG3b+cIgDIA646D5ZcuPeVF1KPE3NepQVJd0smgtpBr4MGMFJQ==',
#  '+C5g7xcLqgff4bvCX54S6w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+CAzPAQGehlQ/04KTap33w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+COICShv0CLANHTEotuZIw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+CYWGFRIchZ/9fJUouWgWA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+CZiLgg92En72wRusKud5Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+CbXDCAlLWXsfQno6inH6A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+D63olvCXq9Q4YWGOcMeKQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+D8K7foM+fCJw3ZA/rl5tw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+DAIyoj2bqIy3m+SAdMO1Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+DPfZYma3z4yF+ZtlbrNLw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+DVHL0Ypf3i4va0lUxWbKg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+DdB0jn2PPsiTUovbXUh5g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+DfTKkHCc62IGhcoc5bgIg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+DpMdJsj9s5OOBJiq4cTu7E8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '+Duo370BiRL9h/jvbtoZiw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+DvXxYnmaqKxrvkD7DjY8A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+E9wvAplOvHyfRoqkjrPvJS3qvn8Fgl/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+EXIpkQpFuHB/bBbQtsAbHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+EY1aEZffr0PMJBKPKetbQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Ef8UtaTybbL7WT9N8ts6Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+EkjcVEol0OV9JrhG9lf8g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Et+NyZx4Fp0Km7/oaeosw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+F7BcsZLoCzLYFDhLjeWBw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FBQdDiV1HyHl1HcBd6/Gw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FM1bU88BkUqrpuzhoqPLQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+FOdwQnJ55jCtgbKfTYABA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FYzGpk3iKR0piY3B2yM5g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FZGASoYcW46m6sXxXhwEw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FcL4CcV5zRTk+V+ILo0qA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Fk1TYpYaW3Ku+KJFum92j7ZtHYR9+HybQ/jHgHWG0kf/bHrn17MPg==',
#  '+FqqRhLRD6PqDH5hMuVl4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+FwDZVhViD9qA637jryqp3b8pH4QURE7NepQVJd0smgtpBr4MGMFJQ==',
#  '+G5pxYhSfQiRP25Akk/AdQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+GBfFMa6MGou7LN0hfyPqw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+GLpEHBoxV2B5sbFoAeuGWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+GTCFyIgrEpi27RJdkAUtw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Go5g2N341sXnkzfNABKCQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+GtdU4i2MsU+Vg9wkmI6XA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+H+S5u9jGdaxEuWFabspxw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+H+ZnO/uvdkDTP5M53/qHWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+H/qe3kbfQ13bAZ2PpIVPw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+H1RwlqSpiGfmalzogXd+w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HEIbrt6S+yZZkwaHok/Lw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HGgPWEW7jzsQNkZSPnoeg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HW7W56EO3T4p4uPkG2a7w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HWvGEMJDh9Z8TpAjjBfHA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HbAYflEv+F0KrK2twCOQw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+HeqxUAsVsD0V2ZBd21WmQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+HfzitHyP1/cAZ/kodB4XQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+HpcatofY00V0nHIJ/rb+g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+IoeuAoa8DgjpC30oOy+aw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ItmNtDeynuo5crIlPviAA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+IuGdJ5u5OxdYhxpAN1lj6i9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '+J8YdD04aKPaF2wuRtTSQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+JBDH3JG46RMzXx4ADXJFw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+JFRFJ0yxYiH+Wl3psA9+w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+JFzbrJCladgTnk2p9gGcA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+JP47lzCIgccQq2SFQ2jrw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+JPBDIhsx89JSqclOcoKrQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+JexYDxWjExqTrK7pKMQhDr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+JnxbiY/aECiB9FGFeo2ww5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+JoMDaW5T3oOTS+qaYl+nQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Jq7rPKPcYWDWNGS5mOWtqi9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '+K9Ji2LjkzGmWygP3Duz7w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+KDELlfn+GwP6UWHYu0fBHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+KFq0GSdcTpeCWOZz0kRbnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+KMGB3XpD46IH0snmXIpNg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+KW1/rqFlM1ZrUxXRg6tAw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Kg9P4I3TAQ0AbpQIbr4cw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+KhwIzUvtlxziRHA7m4dBqi9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '+KlVlJM2Ipyugt++LzFpgw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+KmA33NWDarmOL3ODM+pVA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+KrliQKGWQIKDPUl8gkyTA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Kwpt25MPGWeWPv4kuo7RDr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+L0uJw5BcYJdhUuty2NRbA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+L7drTPueeA8z1mXP0bRiQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LBHtS9sDhRO047KS4LlfA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+LKu+yJHdwvXrCv+m2lTTnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+LPTjEDzXN075udEuF56DQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LV6Ck9r3CGUzsQWsMoivw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LWjUpqrrKMWySLKVFadgg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LY6bX68S/ioHwonWWuMtQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LfITAFR/lbqKxHCgZtYRA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+LmuIkbIOdUPZJevYKZAkg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+M2cvJuNDzEZsHEVs7Oke3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+MLtO1ghRIW4vTwb15zGew5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+MOASd+K58MX0k/v9PnFgA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+MW6E5z62OHXXib7uYuzGw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Mjr3JmzNTkncE6e4OrhPg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+N1xZZ3a1cbvcZR3OJANDQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+N4RKwy0slSAt42f2esQxxyDV19yael++K+fv+DIJSUQ206ntqV8YQ==',
#  '+N9xkzled5uOsZANYxEVcg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ND7jpyvEMvDWYZsb4C7tA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+NNpeBTrV/b+WyRcUeyXxQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+NVp48FegQ4ANKcX/HmTpg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+NZYoDcvtUn+BbaHoEGLvw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+NhozPgcjY7tlU9Q/7NG7GEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+NkQRdLbe5BDBCGuhy4ZKg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Nt8gCRPtW6kTbhHdxSjRA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OCJJ6NTc/PyoEIHTs2eEw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ON4hXB6SlqA2cR+P3JoHQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OTMesMetMXcWyQz0nF/Lw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Okih+Y1JtFqkMNef7512A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OlGZMj2OoP7I6CNwy1mSA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OmNShtGyKaPNPhTddA3OQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OqfiDT8ecaZuxF6PoE5bQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+OtFIiPNWTLXyLgNtkz9Mw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Ov9O4jAdWXpqmlFMXsK2A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+OvW+OsCgIWV3u8VfqrK0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Oyeh8NC/a92hd0Gn7VSPw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+P0u97jloqNt1wqNwxg4MA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+PGpITDfXJ6Hi1npOAwNVA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+PLUFmmvVyiXCa8V3/vlWA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Pawe3sXw32GQf27JaVqZ/6X1LFGXyJMNepQVJd0smgtpBr4MGMFJQ==',
#  '+PcPq1i6DWjSaM/4whzBvg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+PrB6Prdp2mPMvXyS5xyWw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+PucBzbRRXPFI+D3kd3Od3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+Q/13Iw8xwvHYQrS9gHZXA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Q/6WtWkQSFQQ/8pjOXXnQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Q7ws1fOS29Apa4X9lXNIWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+Q8Nfszb1Kpj63buyJJX3Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+QDkktuGINEjSjS7PO/LrXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+QT9s+r+e1qrpo6b1QgbuhyDV19yael++K+fv+DIJSUQ206ntqV8YQ==',
#  '+QYZ7Ir+kM0r5a2vfUi6vHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+QdbBgdZnSRD0Nq9AeKl6Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+QrEmXRtwSbUX8zo5sPN7Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+QwXxg0gudKoMHkuCsckqw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+R+gnBMeBm5sozxaiU4BMA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+R0TNucz3DFk4qmXeqfkXQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+R2X56C/sQBHao5lKlnvDXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+R4PAWtbiDYYPEcIVSInd3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+R9mqjFlY50k5jyblhNqjQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+RXIhoLQFKhUv54CODq/EA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+RfHW491QyA7/g8NcgqFuA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+RmQyR0CeNHQEPOi/q5x/w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+RoGgKs1HzfXAoa8ODxoRw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+RsdasktevWcpsYfTWdb6A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+RtwWOyk8/m3v9VPBnQ4vQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+S+TSGEMPaHiLYLDMG9xKA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+SEKKjLCEWyX74p17th/Rw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+SRNrnQziMff85Ze+7OfCw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Sa4pgBtIDR90/70cgjrCg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+SqvcMJR01vXsVyd0h/rqg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Syca8uc7utpOLxP0nWyCw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+T15H6NChDTNOn2//vSmTA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+T71Pnk5PLWvFDHbGDEQOg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+T8AlhcwghUjpC30oOy+aw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+TJhdRH8xUDMD+ae1/Ld7g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+TdBN+jO8wIHS8WbHYev8A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+TlPh14qGWIeF7ZqW7O3gA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+TloblZJw/z5fOIdmSWI2w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+TpBeBsKsr1PykDqGOgJyg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Tq0KOz0EFn4ilIAjHLZpLE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '+TqK0mTO/UXlcUQt3Aq5hA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+U3+Hd/EA+AexfUJ+2eebQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+UR0W+4K4QfoGf/nmFF6Ug4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+URs4MIe3DiUviPbYEROkA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+URwCD0Ono2AbH4M9wJp7g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+UiHJpYWtKhDuH4C+VnBADr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+UtXnh09NvbpH7hUjUXcJHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+UuLG63XYPaxrvkD7DjY8A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+UzMaU/OeKzm2dGiTo6ocnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+V15mTemqmkA0ucEdQdWxA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VQBC4u2vZFOo70yBDVWZQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VQbsqYiDFf/btw8N27rHQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+VQyab+SDx4Z6sNktJsLLQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VTydRjUlRofr6TRSPIsTQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VUx4U1rQf51zPSt7poHzg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VWeZsyOY1cOj2pW/pgQJw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+VgSo1CndsWRQ9ypTugCJg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+W7yUR4uGbx7A5+EtD8fbQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+WYO7h1MnRLh9UzwVBTdLA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+WayXjHgNSGSUM/EIzfKQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Wdz0fOljcvKV+B89ctJZQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Wg0oUMejiS9SmX3beKIqA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+WkdAeMGQot3E9h0zpaPHXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+WolkHW9HYudRQ3k7IwUV2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+WwvjvQuBLUif49MuvDlcw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+X3AVsGygPVn7JvF9sDCMw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XDnMxzWZ+J7+uCYJGskVg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XG0FZefH6kWKChvuByNKQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XHMwL1RyxjKZc/3e8/ovA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XLO0DkJuPWVNLSpSvguIA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XY/UX2NinIzthd68Rz/ng5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Xi/XRp6NWzZGnqcWLhvNw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Xlbo+15wYrqt12aUG7kpA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XqVTFDR25ORuh2x7h5yIQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+XuXn+dj93dNhScYmhf55w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Y/nsmL+DMw9XLnfBPsljstFfPCg/a+UNepQVJd0smgtpBr4MGMFJQ==',
#  '+Y9jcBH/MDmjWQ8dnxITJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+YHuk4POMvD9MgOW5CKUVQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+YIjhvahDm430LrsgxkbAXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+YIlOXr/uFPmCHhjUETRDw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+YIuE1v8/c9o2puSO3dFGw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+YPOBaIsWpobURY9ke4g2A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+Yaj/xFg0o3uCD6KXwSMQLXQ8BVUBo9gNepQVJd0smgtpBr4MGMFJQ==',
#  '+YkkyCDjWBV77RiKraI/uA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+Z2zVL9Ov1B4edVnPWvauQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ZDKEqZ3WbtkSOPgI1+fwA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+ZSWEtPPy2mFH+OGYhfdNg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ZSdjd8Qhh712r8PrjmMXQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ZfLWalOd4BY90Nbxkem7g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ZkBlAOR/2KeUub36ybuuQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+a+byO3gsSeE+6SbPEs57g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+aA012YGEDMh8J6j45iK9w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+aEzuuftrZiuIwhH0EHj6w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+aISMSzfJJZWp9Fs7GnyzxkAiHjxJeQs+K+fv+DIJSUQ206ntqV8YQ==',
#  '+aVm2K6O96UDyP6nAo1Jgw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+aYfMR/fP0CrYNZcR5SkJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+abhSUOR7KMw8WLnJgmD6L4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '+asvrOuRGL/fTZXdkWzHxQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+b4BeD7WujuRFoJYEncX7Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+b5Ep0V+NPl0YwL0hyTY+w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+b8XKx4YG3/FPDT9A9KxTw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+bGNdYTS60lesfBipFAii74xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '+bHE9Zitn3dvqECSlKglxw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+bJnmvuP7Q1ADgMxrz/AHQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+bNzwvqM9T4rmIl1CFzfYw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+baXXQ2QbKj4RKZSHrTqSg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+brlwswF32W6B4DHJJ5IJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+bvKEhnzSF7qzRrbFiZf9w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+c/a1V5w66qTR2jAkH8SiA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+c5FnlReECSmxYsGmuq4vw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+cEzxUbeaPx2TSLjmpuYFQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cFX2RZDmJNiIkUkpQJTcg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cJCgLydn6VB7WyWgQerTXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+cWbOAQiLKbtv8LNlxoUQA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cXGkO5kQBu+J5DZdn8VNQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cY7VkDG3imOVyRExG6w2A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cg0jo9Bf+D64NEbhd6/jg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+cvxJr6qx6eweeAS2L9cKQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+dAqGNBPJ+PiITpUlaGdRQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+dCjSfgwt63cWyQz0nF/Lw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+dEBBI5rU4KCVJ8FFxmzHQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+dXa4Z+2NqNE792DaMPqTWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+dYW7gcDc3dxuCQid3+dIQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+dqKyy1FI+pHSC5ejp4ggg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+eI40MGIBBZlFkzxS/f1Of6X1LFGXyJMNepQVJd0smgtpBr4MGMFJQ==',
#  '+eW1FpZ1TOrQUsjH7XjCZg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+eb15w4IPkkkzJ64rFwOQKi9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '+efahiD/5dFRzK7uhE5xFA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+emmT2Y3YEIb1RvuKEOa9g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+exlWF/Xut4MhLx7gaJIVQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+f3+MwJS0gZxjlGVmuNzTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+f3c4ufqFIFJSqclOcoKrQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+f5iMyeedfi+leta7XSpgg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fGmNL/YOP4leiSpAaDPiQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fHZA5l/trx+F4bKdsLH1A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fMlGSz8OkaH1I/AMMh1l4AK16iOMFltNepQVJd0smgtpBr4MGMFJQ==',
#  '+fRPuhRK5HXQq/egaZ6oQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fV0bdoyWbj9ErxGW0w4GA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fcalyVwbaxAYZA2xRfFVQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+fiTlfePNpGmRsf/3YrrdA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+fqJSmo/dCDnJXPqnjRZkQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gGSEVMeARduTbU0UlulWQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gHWS04ntAXSNuf1zaJnpw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gLbo+eelNc8wwdeXYfEpg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gOhyHu2n6uVMgSkAJh5Eg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gQ8yrCeXxVa1akPW2R5hw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gcd+ZB69a/6qHXSv6+l8Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+gcdp327nKvWeAflx3xqFA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+gcua+WoxK1mC4hk6ZQJDQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+gpiJ7gmrtiGXLIfG8+v0A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+guoK8NMXaePUu/nT+3VNA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+h2N67oPxE/BN46edUux03AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+hLG7vPO9X963NUtbdAPDg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+hOfaP6skDDKtHhu0a0QyfCCLz/+HqIZbQ/jHgHWG0kf/bHrn17MPg==',
#  '+hbLhYw5HGPuVLowTjk7Dw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+htoIbhmsZwmcz6SQRX2rA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+hvVd8ohdaWI0KT60spCWQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+i2ywXDC8hq3v9VPBnQ4vQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+iMnP4eVYYYdmW9UIrDW9Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+iRZ+b1DJtGKm3tznpDHpQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+idIvAxN7Dm4QqPRosuEYg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+iicQgnELb7G/MPrG8Mhqg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+j+x9T59sTx8JeFVgH5CMg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+jLxgTgzSsPmeyl/XKb8DnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+jPUfui0HZ6PPXJfLrmem2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+jWQVP6w9JuQXezA0U9PlO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '+jaho2DZvaz5aDmPacMx1Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+jeB/7FNvS+lGd2U1uF3K6i9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '+k0UVTCyHtkVyTCK1gGwVA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+k566o9Fy0mI8F9LqtIFCQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+kBq8CtWOKhiYdikwtx2uQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+kDAijsbvgZLro4PItw+o3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+kJAGxOaEsbxHhUQvOtp3g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+kg7ui9xkHqNVqYJXGMtuw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+khH1d+S695hgsngGX8cMA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+kmuf8z5hSi7a5jQ0hQVGw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+kmwt3M1yCz0gz5rz9ZJlw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+kyGIWRKisn9Ktj6vP94yw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+kyRM3KHfS87NpbS/pxlhb4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '+l+Al7VPu2kR5Y+YwozdRw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+l/IGqh2/TzLRklc5Xj8KA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+l4JPoj/cCnx7hrvnTcORw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+lFiHm+fCxq7QAyP/WII0g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+lUqWxeKl6BpOLxP0nWyCw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ldv10DMGs3U3q13HJVg+LE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '+ltbpq33NicPk/8Nlu6FInAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+m3TBvpR5X+mLhWRrX0VQw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+m8Rid4Jx0uopLllTdTjHg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mA6qD3dqYvMxBQUhbi1hg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mD9LYXRKdGX8Xmp7qKv2A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+mDkiZLOVvjmbO0cnXWI0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mETuuH0lfzPCbnf5NYIyw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mGrFZHzK+a1E9k6alErNQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mQmUzcqxXJWR7+Vhg9Zu3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+mSH3hhhSsd3Yj2s3IUaFA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mZOrNotOolMrnDSF8BYCw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+ml0jHjVCMoWSeydose7gw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+mqs5gb9u5lI65fUYd31lA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+myAiC/3StF20oiqJrU8Qg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+n8OEPC+RYPLUII1P68N2g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+nBnJb6EqYkr1BooQnGJ3Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+nFlSCOQreR8sM+69LGv0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+nNvvf9QRbq1E+IOQobfrQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+nOpApH+VKzliZZup2H9KnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+nS0IS3McFpAfnk5DA7olw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+ndsKrmI0a9IWyGkMxmffA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+neEPJIDziPDXFbzglIkpA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+nwt2vnLcjog4KMMbLmG6g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+o/ew5Q2qIRNC2t2smfL7Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+o0atL2JIsBhLph078RCuA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+o1mKESqWhwnA+NFigAJH3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+o23q5LneZZ6VfiO6K4Glw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+oMUl2NRctkj097wUJZaXA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+oVkQewqBnvaF2wuRtTSQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+oXNymuCBxxGdEKBEU/TBQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+oXwJVkkkijsTquRCwj2Gw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+oepJuZUb6aR4zbY7o3fxQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ofqsKnBu6ZjZzpaz4hDZw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ogDh5fKuC3U2T1uzjZCS3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+ol1r9d0Xi04qGaX0Hks7Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+on7jvNLAMcGojulViEP4Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+p0wqvunK2tFxqky5ibOhQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+pEfiIoXnbIjdonXQU79Jg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+pGylK45chH4GXmHEc3q4w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+pWKPXG8NI8lPTXFY+QyjQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+pfALFVN+SugzSk+PeLFnw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+puFWcS0FzZEneVJ+c2iXg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+q/wAB9e7YtPnLXi7OXldA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+qGROmqnJen5wLGi2WeO1nAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+qWHqXAsQQ80Upicr71PXQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+qnCt1Qe1SD4GXmHEc3q4w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+qugmP+ncvupGArUN9ovGw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+qw5geAExxwEBQh39Si99nAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+qxzh0i5bvLE9DkLEN0L3Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+r0bcwWCOjVRr6jLaNBaYQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+rAVoleQjZbVoB/x//AqYg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+rBxtUThu1u40rRur9r9Jg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+rOlegS90XD4KHFx4G5So3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+rVET2Ihkg7xtkrx6hudiw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+rbHqP9iOydVTcANhmwglg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+rmpA2tVXy7YQkaJoyHToA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+roeNpg8QknweJwMlDC/dA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ryAPJ5WGiqw5jqlN02e0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+s1VwBBqKCeCjwaMQPfITw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+sPQ3U9pLYIanl0+TLHkFQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+sRFjClxJeWSUM/EIzfKQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+sebGdlbHDCw1lPEafeRrA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+snhBagCInqWwaB2vYAFsg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+t1zAEqSWKq+s0ryMTbPqQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+tG5mNsFQCXqDH5hMuVl4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+tIkR5vR0sil2XtjMzdfvL4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '+tImuQvNAeQaOiam2meyyQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+tLo1XZHlvYWSf3KelqsBQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+tSbRUpWpQHaatmfH+Gu5g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+tWUTQuZuDNSiJthsVNVeg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+tsrpq0sECJG+P7+7vvPgA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+u0fRpt2FusqskpxIaOIbQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+u5nXFXYoLGo7b+oRN4yDA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+uLDWy99Tu42vGCBdR65KstFfPCg/a+UNepQVJd0smgtpBr4MGMFJQ==',
#  '+uUcCJ9j1KZpNt91Au8biQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+uUjXrNo9FCenErjy3358Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+uVcSEW5od5/T8Tv0D0tknAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+uXauowRnCT1Y2JECj1Fbg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+uYLEZUrvG7UHt7qejDNnQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+uazaXnDDVq3BFJxBjP5pw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+udA98SWrEq6leZxltb/sR51+plkjmr0NepQVJd0smgtpBr4MGMFJQ==',
#  '+uiIyHJt6I0f/twO8sD+Vg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+ukVOTlJidSb2u+gp0oKEQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+umOW0RkxvCvX5X5oos15A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+uuPgsNqyiUDkYO7yzRxjnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+uwIeEvudwLeVATx2vz/FQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+uxk3D+O6idUacpEDeeDnA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+uzgBMsqUp8MsDs/Qjni5Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+v2WY5kT2poftGINmzjgRPCCLz/+HqIZbQ/jHgHWG0kf/bHrn17MPg==',
#  '+v4xXZsvbVvYc5LPSsPb+3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+vBadDRVXqTODg3y/Q7x4A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vDQfMDkW56IKIVdbrIHCg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vQ4j29kcpYiJVU+xGmd/w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vSjAEdZYvSexyqWBBXhWQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vTNQVDaAFeZ4MZQDzRba7E8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '+vZWNBCfTjY3aLWoGTKR/g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vaKZzLMKP8iR4JYwuluBQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vcKRWPur2AiBOYq+3GVrw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vklAov9TXbzUfsbmDzkUQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+vuPOETVZG0KIj9+gdu9SQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vwwB3z7/ZyHR4hrx0pAxg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+vzGl4E9OwEJYn9nZdE+TA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+w1udyOL5X3yTc3hmNKKpQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+w883JekERwFMQyugnQgNg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+wAun6wUJDF8JeFVgH5CMg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+wFfrcI5ZgOW0vEvF74cFg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+wOgb4cqkWxbgrtZ8BQWrw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+wWZ/1i4ObJPtUsnmpLKJHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+wZVcJUw57onmWQxdLWH2Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+waG15UJhfX/O5A9EAoNQ3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '+wg377EdFQlPGSie8/2DBA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+x8XllfEq++ZFKL4QSBkRw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xDmF6NqqGfDrSmPhxyWrQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xMOdDVJHVXPivXucwrIhQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xSSCwYcQglw8p0eAFMxTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xSYdNBj19Pat7n3J0ANL2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '+xYWvIbYTOjTPtvCHJbxpg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xbga7HmeL1X2lsyRL72/Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xfi9vszBtlED4PrdW72+A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+xj/uCbFBUEfyAe2BtnKa34m7JzbaZ2RNepQVJd0smgtpBr4MGMFJQ==',
#  '+xl0jbSUF5/AJ1kWGP5FQA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+xpZIGg9PiJbGB+bbhjniQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+y6Xo2t82P06w7BF5wZ/CQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+yGKe6XqT3ttObl5YmrGZw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+yZSDSYzRy67Yvam9aLP0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+yZrqBR2YQiLleEV+6X5Mg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+yupqJE9alsbAPV9qdRQ+g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+z+Wyg7EblDben01t6jWS5S3qvn8Fgl/+K+fv+DIJSUQ206ntqV8YQ==',
#  '+z8eGROL9/Zg23j5Nmmyyw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+zchQ56Cvcpa3NPkhXGaHO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '+zjhZDKIGNWZoTY03HXWKw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '+zjovWJAQZ2sA2IRA52ciQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '+zvF+FM8ayD3QJPSYjwgTWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/+I8T5iL2a31hq6Q/6260nAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/+LlO37po3p9RK/IOQJueLE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/+UjcuhrYYHDI3MU3fgyPw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/+b3J/bqfV9SvYrv8dSQYw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/+nVozGBud6V3u8VfqrK0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//K0bnlSp6d5vGBU8zaUDw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//K4xYWKXiqLVAQscZtHCA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//SEgYPMJN9wo6O/E5HxJQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//cgpOhuwNWG6ZYWEGjCMQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//pVYiuZvOBJdiqIc0BVOg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//tUH8RFXhcezqAKqtLSYg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//v0U7rh4XBkq8QHhlqFCA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '//yH8PNRHH9oAG1q/pG0hA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/0+SAlih8WKt9B69LYQ7AQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/046s/hrvVWssBPH2W35jg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/051ODrgNsEoqYa+ogSuVw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/08q1kKFiRVM7o50hbJLyw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/0Issttuz9mGGuf9ApYEfw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/0W0OyUlTb9+EdhEwQRHBA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/0q2ErsrfaGt9B69LYQ7AQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/0sb8yzr7lLpXLgJ1ncfdg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/0vRvvbigc6K4ROf/IVIcA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/10ImUFi11c0wkcpn7AckQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/1GwHXd+0ME0O8BmN4gdew4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/1Rb8fSvTmkuaNSJXBWHDQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/1VwglDDkXs/mPG9mkVJ5w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/1XRWhQ64dz/mjMh71ayPA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/1comSbjNxecb/AQ0nc/oQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/1hnEkij5A7cMANXPh1pQg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/21sXBYrX4oH9y3H5eeL/A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/2642HcTZ69HnlFrmiGi3w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/26t4LcRfVv47pnJKVmtxQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/27oexMXBR8heSrke6VOMO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/292p4kezOKZmWrTpKNoSg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/2IXv5Y7hpiSuRw4I276lQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/2P7YptJPrAX8mqkX0PMYQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/2RDWgaDXhZYayg9nq79we0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/2znsNHGc7RMy3VwzddSpA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/31peOd3A6LrERyl9rXe6Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/3DSAn203iQwJODs6pf2HQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/3iBk6m9HYMRU5Y3GgATZA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/3u/M7p4FkTIxSS2qgBWIg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/3uepDYBNiWzYN2SeYiJ5w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/3xbN3PorVIJYn9nZdE+TA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/3zaGbCsmJraF2wuRtTSQw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/41s2fWkLwocgltDvU6EJw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/4DpJiEhlxPKJf3L4MxU4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4HBEzBgyrSKNcPk737vmw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4KroPXib6n3wyQTYoAqgw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4LwQDgtMrDqDH5hMuVl4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4OC185E89X9rwM7XGD1lXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/4em28M5gkUUf+fooQSzfQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4l0wiq+EkK0WmUzAt1jKg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/4rjIA8RyAzOwvaRKBoYpw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/4xhDaLXEcJO9/epFvLsZ3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/54PJUN/5HaJlSFymrXp+w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/57tRx5Iv3uRqNXETBHMRQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/58IWaRskPupySuW+c3UsQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/5FXJ8GTiUWVw2xJbzOsNw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/5l18DYXABX2SUVjR4HS9g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/5tNfLnmZJxilIEeZ3UCnQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/5vM2YIeJE3cqB8fqs4xvQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/5w3l0eQkdyNWms3R4+ziQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/62mW27tm4GMBXxNeagDNg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/6Vrw2m/bKlKe6rYqyE57g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/6WguPQjV/oR1pQUdKWE+g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/6iblC75836DdS2XI2HchrE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/77u9RxDbXCN9VJcbFChyA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7BI16DGc1rnkG65S26fdvvRBtLQxRYONepQVJd0smgtpBr4MGMFJQ==',
#  '/7IDTEwPTriuD/65lyi9PQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7INSzSMmX/f0x8QQEa+uA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7TLYTHYz43cQsnfgEUXrA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7WEAIckzlNebeGQ2a9JoQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7hoKOnsz4I5cvuClrew8A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7mWTSUn5wYug4A1NPT4hw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7p6995gGA3rbG+Ff3goAQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7qC0UWdiQSkN/cK5LVs7A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7rg2OHbqUE+WukF14sTpQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/7tYZsfz/Qty2X0QhmTRJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7wYDXcACJvmZS76PFsy3g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/7waCWNi3OMpT0hiK/x+Ew5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/81DIOYHdgIx0U6RhvCC5A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/83WWrHStMBDbgHJampboA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/8BlIP4ugWZF7eOShAyVwg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/8GCwbCbLfjn1ALM6Eiz2Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/8IUsGRPsWexg3Q2rIXdtXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/8YLhZbZ7Aieb9ur4mD7zQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/8YbbBbXiXsfDguHOrIxjA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/8jzimhZuw93x9guVrcqUmEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/931lCo9KdGl6J8Y+i47rg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/9CDa5nmvGJwuS28FcTR6H4m7JzbaZ2RNepQVJd0smgtpBr4MGMFJQ==',
#  '/9GNCpIP27l54Kw1U/tMXA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/9XZn1dfisLNXoFiiZEMCg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/9zCsIRsLa5iYTdkMceDCw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/A6ahuJLXCrHrdcH++D8Fw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ABrM4IjVuz/2syuAm8YEw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ANqbM1oF++9+FAOYlovHA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/AOEL5Vq6586PFsvcDUyng5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/AT9bYsCOmudsJLH5/BRBg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/AcGyCx8Nv7b7UNq/aWJKQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/AfNp4esEXYt1TShf83tGQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/BFhnvd6dS3SaM/4whzBvg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/BMllvogbc8542YBQovLDrE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/BMyQ/U+FEnFn5vPyEqLtg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/BO61Fp5Mr9QouE7y6kUHg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/BU6pj/0vW+1GU7G6SLbmQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/BXxPvl7iKozGF00sTtzlA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/BffMKZwLs3EPp7vriJEcA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Bk7QcHNgZFCGBVW0YcpbQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/BprO2fD9BgWtWncd0Ra2w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/C2jy67ZAQ8NUqwmf2Tx5Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/CDEp3nKjGiDeUiIawP5y7E8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/CDJYUvDwXf2A8kGknKvXg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/CHbe1JUsDKkz4Jp3KH93g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/CcOImIyx7GR0+4PqpWpwg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/CeXVRu/duwAL8d3b1w07g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Clc9jOYmhJ7NhdMEPNqog4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/CmlaV8e/YO1SS24Nxidsg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/D4yM5nEtHOZMZo0tFJ8Ww5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/DEuKgswPVyCbV0ILXglTw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/DaqdvwTmfaZ91XUsbY9Dg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/DkTk3jghnufKb0flqv/KA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/DsM4GNc0oStB+nVw0FsyA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/DtwS9vRATwSktgrwdtBtg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/E2Mw8hU+L8OnxDjD1IwFg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/E2scgb9Xo3DIrFGDXcFjw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/E69nOnJIY83JdaiLabf1Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/E6SJ9jfoCp9zP+5FocPBw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/E797oDPMwt5S4K1v9RJnw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/EQx/qILAT7CjNrha6bvDg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/EsOI1Y62NnjbPJ21Jnzhw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Escai19mKOLbLHqQfCjlXb8pH4QURE7NepQVJd0smgtpBr4MGMFJQ==',
#  '/EzK5FLhV+o7DkdwMcuvUQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/F1rw6+K4e2AZzt8xmsdcA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/F6x/kWquKSt1YQ/ZzDYFQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/FED/erVWxFffUU0flyiYQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/FNJfW7+jyMVQ1DIS/MsAA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/FVuPdQjvufZHhHUXjsViQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/FXRdEzfui2+J5DZdn8VNQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/FjX3zetmUrDe6rDqknlcQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/FlcZQo/8Kd9zxfCe3ihvA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/FpEZtCpv3Ov9dZt+UiiSQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/FpVFzMYDJQY2RJbPgYnpA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/GADLi14YLETVaLXtSiqzA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/GGuxvbDPhTyl2uN+tlvbQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GKK149XQdpv8OACC7ekkw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GMVRnxI19Cd0n66CCWi7g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GNa5pDqjtYW8SAyv9w1aQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GPHVLlLlvsyrSCqJeg6cw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GQtGi0UGKfUtKZ/5Llwkw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GY8o1P7lf7XAoa8ODxoRw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GaQnReflBvot5fXD9955w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GcZrKy9zzHn4dojBKdLRQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GeonC7gwghHSsCz5dHUmA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Gk+Y/e39Blb5Rfv0GfPug5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/GwkfpYwnLU0L1MNBtUgbg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/HYoX1/4wf//soXQ/FYgEg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/HZF69800OgOY0yDcTVMZGEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/Ho0Xtw4ED1YmdV6dO79QbXQ8BVUBo9gNepQVJd0smgtpBr4MGMFJQ==',
#  '/HscYlysc4lILwJ3FKlkYg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/I/4+MjpjyJ1Al9ImeZUvGEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/I8I/149QHwqO4EfWgk+c3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/IDo73ddw+q1GS8jWQglyXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/IIMKIzJ00YV7wg7K+3NiA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ISW19gH/UWWzqY9A9yb4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/IaRJ6lfC1FWopdugRlcjg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/IrItuwb+pRaYcMgPIdiTw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/J+6zAuCzyFyWBrVLicnyQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/JyxD/fXxaNiPFEW0tqu0r4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '/K0w1wZvHRwQIFfWADm4fA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/K3K4PpcGIR3iXCmbcAp+Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/K3dQXoOuPJbpDXLD8QTVO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/K534na+sbGVNLSpSvguIA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/KBic9TkIQW7uTJA3qz3eg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/KGtl4jcIuL3X3h2eGj7rw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/KRlZy1+y3561L1WSrfEOR51+plkjmr0NepQVJd0smgtpBr4MGMFJQ==',
#  '/KiU13cRbWlQiB6b8cs3Ug4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/KrSc6KbUKytIkffWVZ5ow4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/L2norGvixR6RCWHZ8zKxw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/LBt8SkNSUCLbqnSvZluZA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/LCWyJzuR6aqNAdFItKOPw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/LDshlFpeK9L972ysY9o1Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/LYshoZ2EO7JlZHzBlqSd3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/LZLztTjqtDd4Y2MLtZw0Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/LZd6xfzJutpezqcGaHvfA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/LvU4h4mam9RZiUYJ/cAbHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/MJgtqHs2CcgIRDRYM9Hlg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/MNvw+Q0YOo7DkdwMcuvUQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/MaWvvv89p336jCzOTllcw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/MfpeA1O2zlQDTASD26iLXT9TkL6xmYnNepQVJd0smgtpBr4MGMFJQ==',
#  '/MgNeyov9Fb/B/mqOfvFZg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/N2mGwmi4fzSjQ4P8bASOw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/N4rWezlKjVAN7zsRjUKLQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NAi9mWELvojwWpsr8/Weg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NEgZmsvruGQhl7UktkNinAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/NH71jGSKY2HTXqRepoQjw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NMftCYK9rLPivXucwrIhQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NT1slTDX8rmOL3ODM+pVA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NaWysXv98BE+0r4gwZdag4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Nb1xLux/0C6bEbmf6z6og5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Nb4ogt4J1N894nQVPjpYg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Nfo89RgSKYzIfql3vpMbw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NhvVneHRq0rwOTVZ5+wqQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Nlx9pcGb+brxrGG6CwG7w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Nqs2h16Uq3qO3oX4/iEdQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/NtzXOChjIiv5yy6DdGBig4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/O1FHPZNhsPmD822pDlOVw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/O25SBeA29k314yHDXthow4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/O7c+exfxT+ZAJbvlPAqfw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/O9orbvZyMmoO8oiYxE/Iw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/OAN1c7RreNraXSYRH8+BA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/OGQj5F3+U/B2O7RTS3KiA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/OJxZ2YRC0n9tuEGXivsXg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/OXmnIvQ4JEJwDIeTQjjmQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Odx7pyie53jgFFqBNBFMg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/OhUUEWYqsGD2NcL8QjtVWEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/P+d7LBU9Py71RJtgahxIL4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '/P2k3BAlL8iZmWrTpKNoSg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/P37w6F+aEx3fqDCUYw94Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/PGkLyv6IoGox1Of9aFkhw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/PJkVsD8GCsn3ceNsC4kvg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PQBHGlkYK3nZ017roDMRQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Patu3cO/3RCpxS4Tg7y+A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PjjdmTQGdP+g0BVJxkFsQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PksAyImIInApgCuWVCb3g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PvBMFNKfarpnx11V/fUyg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PzAhUXqsLV7broPqyO/YQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/PzJ0jkpMDUCYt4gRhtrxQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Q8yNdhIVrQ4P/mH4gROpQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/QCkbCQyyoTWkPSk50FK0A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/QTUDaKtS6ff3VUqX1CYIg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/QffwvxAXhIZiVWPFDMvIA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/QjnHuUZ0VFqcVRqsinrIA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/QoMdMkVug79Ktj6vP94yw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/RBrMxEBNQsNNJrNep0W0w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/RC37rh2RQ6VFjEo+KkoGw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/RNze3WJJApOZrnhvkaYBA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/RSPK5fJ65hd4wXZMTlr3w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/RTBOcZGVsXmyWxnYj+njg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/RZqQoF36ufK97MrNSPXzrE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/Raaui5w6T80cwq/nbMgOw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/RjuQc6A1N/XNGtrdAxKEQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Rl0AsJEqAym71+RE8lT+A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/RyI7sSS6xovhvGat4f4OnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/S608+qMjFmx230S259gFw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/S9FCANUXx58Tt7QCSrTqA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/SFDMd0db4ZuKqxBMUUi0g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SJTPQgyL9GXzSc29H6sJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SLuj2jW20cvuiZHBLQpLA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SOkEj6kOZJTKqVEOSnMSQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SPIxDgg32NXwdrDjJwQMQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SQ7VMP33ZJuTbU0UlulWQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SSx9vy1iJxHSsCz5dHUmA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SX9d76nOQZJGqJOv67O2A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/SeFItnkLHl/Rv2gW0pYfGEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/SeqlyATK1QZ1CLYAccp2Dr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '/Srk42Cpfz38wz9CtYhdKw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Sv3HSeXOg2XNE2OxWbGIXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/SxF/iXp1nZqPsaVbh5Weg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/T394UY7aqlgJnAkp3ibow4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/T5bjTyZ3fItNK4BfBwgibE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/TDljzgDrv5D3kVNkF0R4A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/TS6naO4/nH6XmNvTEc84g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/TcPdagW7SNCPiug5bDpfQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/U+/poFqhLOLhOCbcXj7fHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/U+qoq5nSVI7sYEnrd/lzA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/UHXFBPvt/92wtDiOFqKaQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ULFovfj8IZpW45qiYkhfA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/UMZcVT0mtnjfPm69NTEag4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/UPAr16xP/ZLc9NftCIiDw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/UgEqiseLsEWGSrvjNThh3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/UjQtc+uiHu1pY+lko1xvQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/V1ssM/tik2mAfGLRWj6dg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/V4iYRhlGS/xE1C3MWgRsw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/V5fLg0uFoG+gI+8T3wE8w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/V9e3ISrYJux230S259gFw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/VHgBHvefV311f7geAqPVDr+/k0/DTn/+K+fv+DIJSUQ206ntqV8YQ==',
#  '/VNdsTqk8paIXsWBFDXPxw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/VYAifoxcSwyHdopKDADjHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/Vg/hYcp0EJcWfcapEKziw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/W+EkWAixzOkUT15ZbVmlQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/W/dl80k3b46hbWbvFiOZg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/W0jG0UH9HjfGCZDXPTyX6i9GDTrmiNZNepQVJd0smgtpBr4MGMFJQ==',
#  '/W2drwuCkJQcUe96+IsDyA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/W3POMURzgnRJWqyHphSPQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/W5xyuhq5Rr+VBREOkwtZg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/W9rjwex/bPIx3LkNnT4zQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/WAfyL0FiiP7Cg1711wyeA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/WF80QnVm1uJjHOkK0EbVHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/WSXCqD5MlxEp9aqBgo0CA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/WZ3SzjPvUP7zSfJqs10hXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/WeX2X7hxglxRl2025ZR2w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Wp0eHhg3olQW6DJEFAzKw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Wv/rZSK/kEnoGq4kHjzlg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/X7uvf9dNSZ3iO636ErMJw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/X7v5+1eu2rv7ED/zT7GBrE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/XBCj+VmRYu9nQG4cW2Aiu0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/XIjPoLDlT4/VaK/cCEJ3Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/XUJatNYJ8cMMbQVyG/mdg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/XVK3UW0Y+mlwl/zf1SKDg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Xgjl664j7jwGgeEMIPDNw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/XiA59oL8f6rpOYKEZQb+Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Y1pqa4HMbp6V6B+RTZzgQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/YDeEUSJrOGSN2mgHsyBWw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/YHPVax0QgUIJ7GvbYhBVA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/YIyYFiIj6fxYITlQdoWrA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/YKJNXOP7I3F1W7HGCZj7g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Yc8Jpy+Q8O/Z7Be6HiAqw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Yff42xzfkbk3Rl4U9CgUg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/YgN9zIEJxhm4WNdUfeO9Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Ym4SMKso+auvDmQ/GAuwQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Ym8SMCfO5QIEgLc8aBmQA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/YnhlzyX7chc7FRV3TVWFQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/Ynr0O6BFaftJqmWoykgBg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/Z9S4xVBWlJq2nHSnQZF+w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ZAuI0XyGWuMLQsdEXIDHg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZKY6lsojFB5tlrLSz1KmA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZP1vNQxYvEd39U3vr0VKQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZRpLYZe8w5359+kbNeXxw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ZaERiyEu5dF5usWWEadig5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZhV2VLYf7NeloYLQ2Guxg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZiFrvC1KR+weeAS2L9cKQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ZkHtLxh4HOwGgMf3kUYdg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ZvS3H1TVN+R6bRM7C7yCg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/a43IRYFnLfSnX9wM6MNL3AG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/a6mOZ4zbsKVFVXIK8PClA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/aAXhCYiDevuPggz3+Ld7A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/aJJNDX2l23CThjYsQevKg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/aMY8xKKlpHh302jMyjx2Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/aTfkb82jsyuxlN+15f6s74xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '/ae7th3moTo2x73Qv44uUw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/aiSwWhFP8HFbFVDS/4ScrE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/avvngK3rJBojm8wwP2JQg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/b7tUaqj7W46T+105cOI+A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/bHydrWzOY5I6UNDqI1l5Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/bOdgOKj5RBILwJ3FKlkYg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/bPYKez3HyQ9Ntf8xXxK0Q4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/bVAQo59u1hZlnwITX0MvA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/cOk4clqdb4gzKU2V0AqEA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/cPEkITNXAmTkA1oqZbJYw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/cbcwo/9MLGqK+WajNoyHQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/cjGVexm4sXRJWqyHphSPQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/cjXWC7rfZ1tObl5YmrGZw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/clMTet2M5Z0xMZ3oXj4ig5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/cvR7Hh3ugn+3SZ0esArVQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/cyrkvPIDcK1flGnpqG2fw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/d66YwShtwRTkAdLthtp2w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/dDAc0N70/grx0HyJK9yGA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/dhcMAQ6c6g/QyyjRgBjdg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/djpvrkVvQa2JTzpiWvJjw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/eKm0wfswKP/tbIAM9PfTQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/eM3yvq767hY+WvpcOGCTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/eMtIb3ab/PTfZbRd3ooXg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ebI0X/zlO2b/QlfJTJhiw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/egMmqd6wxmvUNYMhxxMBw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ekg6CotkX+lfN492YWkhA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/ep2pWgNjAxDUnMUPF/fBg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/es8PLcTlbmQnFHM4NPGCg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/euyLxR0QZNCOhWdLeWcrA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/evpaGjgZvNNjn1vWKMZjw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/eyZKILvky/PivXucwrIhQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/f8R7Zc8ZHVbIMgtHizDeg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/fNG3bSxPKMYM0AoAAO91A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/fUkPcN6IcE46s731rb5zw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/fhuyJgtWkzngs9ABQyh0g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/fpB4euNDaDZAoTBHLf2Gw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/fzvdbvdNKBfm8b3wZDuew5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/gB/GoUgLgtfT7WXstfpKO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/gaWXlaryYLPjeLM3AM+HA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ggEP2Cn++aGksmjj4ymQA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/gt63NZCwLzHE5laNY/1WQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/h/PCvKKrCL2MNJcxEPNqA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/h1wbrC2OUGdHLFeHaQj4g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/hDetOm8e/T55Ox7sUaRmw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/hIM7BURpRsUYIKN2scUEw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/hN7otsQAZ2nBSQDrjsB8w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/hO7G7SvUpIj9XxwUq5Hgw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/hVc0/0O9x8xoEuOFVg3lbE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/haBrAdnHpFyyv+RlT0wsg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/iEhTY/ifc8wVZ6SnB9MqQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/iUCkuisjQl7+uCYJGskVg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/inELv/xRD3InvyiRng9WMuPeVF1KPE3NepQVJd0smgtpBr4MGMFJQ==',
#  '/ipsVUsJ4Uk5DWb9gRbS2Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/iyw4DidXWFCchb44Uxoxg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/j3YtqJowBCiQdANoRG0rg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/j5d+bVjNEUxpmvj47As3HAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/jGzJDGxUzuYC6dqUwzIIByDV19yael++K+fv+DIJSUQ206ntqV8YQ==',
#  '/jNkVmixYP2l0L6s+RAgYHAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/jP6qzBtjp0yrSCqJeg6cw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/jfLroeuhLw3XK1//lUE6w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/jfUEqA9F9E/QyyjRgBjdg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/jgcpBSsYceNSugDn5kJLg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/jgyOx9rgtO4eilqk8th9g4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/k4Eurhgld11ubUO6PEWeg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/k5FBwSIkUOSVyfYRiKKDw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/k9Hc/PEgwxjS+9/4bTYWA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/kEA+fv8f4MOOcqW1zPicw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/kSnqNekYB0X148c79/z3w4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ko+5rg+pA/QF6movoBPbQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/kpDREgloBNAbf/5qAitKO0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/kpDREgloBNsqI/6IZpSzQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/kpaxUZ8nrKjf+44G4ALlw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/kraEAxYW/40tC+kY+rpxg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/kwjMq1mCCrhUst9XwIMdA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/l+E/dE9vzas1oKMxzPaOXAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/l/NBTDtNDd14vlFYcnmg2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/l21jEXMN6CmLItyYiybfw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/l3WsHfnJ4CCu1hE8p6GLw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/lBEA2RPGfxptRskSLD5Fg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lHNbGMsdABa9NutsDO3dnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/lK0ItbMdAYUY+iySUqkUQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lP2HiErd2KXzSc29H6sJA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lTxOrSZoCIyWVPmadCpeA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/licQbR3qKdv8Ky+TNBq0w5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lj14MAQT1zzMsG0WIZXiA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lm1zaI53SruPops4fgg2A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lwIjmd936nMj7Z4dbgqaw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/lxcW002ddT7I6CNwy1mSA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/m1UvKSWzzgzp8SBZ0Rrw2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/mNw8Kr9qO9T3YwWe2iPcQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/mOxiN110w7aQmpXMKeKTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/mSCi9d8IT1Cwx9NSiQW6Q5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/mheOM40xC8k2csPoWk8aQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/mpX/gx32HZ7CFDkw08zZGEWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/mwsysSyr7S/IzLZl++HFw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/nEgsCgHNc8GfUZdynDX/A4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/nIU0ti/T16O4kXoABBsuQ4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/nPUzpzzr8RCSUCi6tgrKQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/nThFtUEpHGYvaK5vzkN0XAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/nfdKEaiY6pEJ5NGvVbEKHDUQ+2wvZXmbQ/jHgHWG0kf/bHrn17MPg==',
#  '/ngH1fQW0Qe+3zW6II4x3nAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/nrlsRkK3+H2iQo6votDgw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/ntypSNuKp7aQmpXMKeKTg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/nwAk2DWg+DmhbxZblczBg4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/o+M54k4Ub+QwJOY4dxvMQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/oAXUo8Be3RKyVpBHNSaGQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/oC/577G4ihstIKH2U+p0A5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/oIrEG6JfvLU9Ir0R7TqTbE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/oJaMWzgW+zS7KDY9I7gdLE8KztNWz3qNepQVJd0smgtpBr4MGMFJQ==',
#  '/oNaTmXsrHCNIgyEOz4nzA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/oeNbcQcUUPP3mUD5VlsHL4xbHqlXxy8NepQVJd0smgtpBr4MGMFJQ==',
#  '/ooRIBB/mvO3WrAhkVrFVA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/p6QVXXrWP80tC+kY+rpxg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/pBnmHgn0Cuo4hFCYhuW0g5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/pC9XrxMgvRNT+DudqZflw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/pYyMKGPvVHAqiak+HMaDnAG1BvSkUYANepQVJd0smgtpBr4MGMFJQ==',
#  '/paYSVYMIVlOZrnhvkaYBA4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/peEETQ+IVCkqGKmKW2wv+0FTBOaGwQqNepQVJd0smgtpBr4MGMFJQ==',
#  '/piYqNZaFDUX62+VW/c6e2EWBgzjpZvPNepQVJd0smgtpBr4MGMFJQ==',
#  '/pnuGaJeCN35BdnK7gHHPw4ZM3TcQvn1bQ/jHgHWG0kf/bHrn17MPg==',
#  '/pvRg8RJdgJx5o9mHteyEg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/pvdTAbMTveA9+kCQV57Mg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/q+SpekIqhfWgUVA3TEyzQ5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/q3H5/Yk99w2XRyt3JcFIg5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  '/q8kbGxmi5VrWb3RCGYqYw5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ==',
#  ...]

# %% [markdown]
# ## 2.2 Splitting the data frames

# %%
def split_df(users,df):
    df_train=df.loc[df['user_id'].isin(users)]
    df_test=df.loc[~ df['user_id'].isin(users)]
    return df_train,df_test

df_positions_train,df_positions_test=split_df(training_users,df_positions)
df_education_train,df_education_test=split_df(training_users,df_education)
df_seniority_train,df_seniority_test=split_df(training_users,df_seniority)


# checking that we still have every user

print(count_users(df_positions_train)+count_users(df_positions_test)==count_users(df_positions)) #posisions does not have 100k users
print(count_users(df_education_train)+count_users(df_education_test))
print(count_users(df_seniority_train)+count_users(df_seniority_test))
# Out:
# True
# 100000
# 100000

# %% [markdown]
# # 3 Data processing

# %%
from datetime import datetime
import numpy as np

# %%
class DataTransformer:
    # to preven data leakage
    #class constants, used for test data too, but they are only changed with the training data when fit=true
    
    avg_length_job= avg_length_edu = avg_end_job = avg_start_job= avg_end_edu = avg_start_edu =0
    
    TEST=None
    def __init__(self,df_positions,df_education,df_seniority):
        self.df_positions = df_positions
        self.df_education=df_education
        self.df_seniority = df_seniority
    ### 
    def format_to_size(self,df,labels=False):
        def to_fixed_size(df,cols,size):
            for col in cols:
                df[col] = df[col].apply(lambda x: x[0:size] if (len(x)>size) else  (x + (size-len(x)) * [x[-1]]))
            
            return df
        
        return to_fixed_size(df,['enddate_y','startdate_y','seniority','enddate_x','startdate_x'],10)
    ###
    def get_labels(self,df,remove_info=False):
        df['label']=None
        def get_first_index(mylist, substring):
            for i, s in enumerate(mylist):
                if substring in s:
                      return i
            return -1
        for index, row in df.iterrows():
            i=get_first_index(row['major'],'bachelor')
            birth=row['startdate_y'][i]-18
            if i!=-1:
                df.loc[index,'label'] = birth 
                if remove_info and len(row['enddate_y'])>1: # remove bachelor info for training
                    df.at[index,'enddate_y'] = row['enddate_y'][:i]+row['enddate_y'][i+1:]
                    df.at[index,'startdate_y'] = row['startdate_y'][:i]+row['startdate_y'][i+1:]
                    df.at[index,'major'] =  row['major'][:i]+row['major'][i+1:]
            else:
                print('ERROR COULD NOT GET LABEL FOR USER:', row.index.name)
        return df
    ###
    def merge_pd(self,df_positions, df_education,df_seniority,labels=False,remove_info=False):
        # sorting by startdate for later:
        df_positions.sort_values(by=['startdate'],inplace=True)
        df_education.sort_values(by=['startdate'],inplace=True)
        
        df=df_positions.merge(df_seniority, how='right',left_on=['user_id','jobtitle'], right_on=['user_id','jobtitle'])
        df=df.groupby('user_id').agg(lambda x: list(x))
        df_education_temp=df_education.groupby('user_id').agg(lambda x: list(x))
        df=df.merge(df_education_temp, how='outer', left_on='user_id', right_on='user_id')
        
        df['startdate_x']=df.apply(lambda row: [max(row['enddate_y']) if pd.isnull(date) else date for date in row['startdate_x'] ] ,axis=1)
        now = datetime.now()
        today=now.year+now.month/13
        df['enddate_x']=df['enddate_x'].apply(lambda dates: [today if pd.isnull(date) else date for date in dates])
        
        if labels: # add labels
            df=self.get_labels(df,remove_info)
        return df
    ###
    def transform_pd(self,df_positions, df_education,df_seniority,fit=False):
        
        def to_lower_case(df,col):
            df.loc[:,col] =  df[col].str.lower()
            return df 
        def to_datetime(df,col):
            df.loc[:,col] =  pd.to_datetime(df[col], format='%Y-%m-%d')
            df.loc[:,col] =  df[col].dt.year+ df[col].dt.month/13
            return df
        print('changing dates and text format \n')

        df_education = df_education.pipe(to_lower_case, col='major').pipe(to_datetime,col='startdate').pipe(to_datetime,col='enddate')
        df_positions = df_positions.pipe(to_lower_case, col='jobtitle').pipe(to_datetime,col='startdate').pipe(to_datetime,col='enddate')
        df_seniority = df_seniority.pipe(to_lower_case, col='jobtitle')
        
        def fill_end_dates(df):
            now = datetime.now()
            today=now.year+now.month/13
            #print('today',today)
            before=df['enddate'].isna().sum()
            df.loc[:,'enddate']=df.loc[:,:].apply(lambda row: today if pd.isnull(row['enddate']) and (not pd.isnull(row['startdate'])) else row['enddate'],axis=1)
            print('added',before-df['enddate'].isna().sum(),'values \n')
            return df

        print('completing position end dates...')

        df_positions=fill_end_dates(df_positions)
        print('completing education end dates...')
        df_education=fill_end_dates(df_education)

        def fill_startdate(df,typ):
            df_nona=df[['startdate','enddate']].dropna(how='all',inplace=False)
            df_nona['length']=df_nona['enddate']-df_nona['startdate']
            avg_length=0
            if fit:
                if typ=='edu':
                    DataTransformer.avg_length_edu=avg_length=df_nona["length"].mean()
                else:
                    DataTransformer.avg_length_job=avg_length=df_nona["length"].mean()
            else:
                if typ=='edu':
                    avg_length=DataTransformer.avg_length_edu
                else:
                    avg_length= DataTransformer.avg_length_job
                
            print('average length: ',avg_length,'yrs')
            before=df['startdate'].isna().sum()
            df['startdate'].fillna(df['enddate']-avg_length, inplace=True)
            print('added',before-df['startdate'].isna().sum(),'values \n')
            return df
        print('completing education start dates...')
        df_education=fill_startdate(df_education,'edu')
        print('completing position end dates...')
        df_positions=fill_startdate(df_positions,'job')
        
        def fill_dates_missingall(df,typ):
            df_nona=df[['startdate','enddate']].dropna(how='all',inplace=False)
            #df_nona['length']=df_nona['enddate']-df_nona['startdate']
            
            avg_start=avg_end=0
            if fit:
                if typ=='edu':
                    DataTransformer.avg_start_edu=avg_start=df_nona["startdate"].mean()
                    DataTransformer.avg_end_edu=avg_end=df_nona["enddate"].mean()
                else:
                    DataTransformer.avg_start_job=avg_start=df_nona["startdate"].mean()
                    DataTransformer.avg_end_job=avg_end=df_nona["enddate"].mean()
            else:
                if typ=='edu':
                    avg_start=DataTransformer.avg_start_edu
                    avg_end=DataTransformer.avg_end_edu
                else:
                    avg_start=DataTransformer.avg_start_job
                    avg_end=DataTransformer.avg_end_job
            
                
            print('average start date: ',avg_start,'yrs')
            print('average end date: ',avg_end,'yrs')
            before=df['startdate'].isna().sum()
            df['startdate'].fillna(avg_start, inplace=True)
            df['enddate'].fillna(avg_end, inplace=True)
            print('added',before-df['startdate'].isna().sum(),'values \n')
            return df  
        print('completing education remaining dates...')
        df_education=fill_dates_missingall(df_education,'edu')
        print('completing position remaining dates...')
        df_positions=fill_dates_missingall(df_positions,'job')
        
        # filling missing education and positions
        df_positions['jobtitle'].fillna('positions', inplace=True)
        df_seniority['jobtitle'].fillna('positions', inplace=True)
        df_education['major'].fillna('education', inplace=True)
        
        #filling missing seniority information
        df_seniority['seniority'].fillna((df_seniority['seniority'].mean()), inplace=True)
            
        
        return df_positions,df_education,df_seniority
    
    ####
    def transform(self,fit=False,labels=False,remove_info=False):
        self.df_positions,self.df_education,self.df_seniority=self.transform_pd(self.df_positions, self.df_education,self.df_seniority,fit)
        merged=self.merge_pd(self.df_positions,self.df_education,self.df_seniority,labels,remove_info)
        
        
        return self.format_to_size(merged,labels)
    
    
dataTransformer = DataTransformer(df_positions_train,df_education_train,df_seniority_train)
train_data =dataTransformer.transform(fit=True,labels=True,remove_info=True)
# Out:
# changing dates and text format
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# completing position end dates...
# added 34191 values
#
# completing education end dates...
# added 2595 values
#
# completing education start dates...
# average length:  3.6164438974724713 yrs
# added 533 values
#
# completing position end dates...
# average length:  3.973643719107162 yrs
# added 25 values
#
# completing education remaining dates...
# average start date:  2003.295803705871 yrs
# average end date:  2006.9122476033924 yrs
# added 9072 values
#
# completing position remaining dates...
# average start date:  2010.1666330822677 yrs
# average end date:  2014.140276800845 yrs
# added 2314 values
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
feature_cols=['enddate_y','startdate_y','seniority','enddate_x','startdate_x']


X=np.asarray(train_data[feature_cols].values.tolist())
# matrix dim for emsemble method
X=np.reshape(X, (len(X), X.shape[1]*X.shape[2]))

# gets rid of future warning
y=np.asarray(train_data[['label']]).reshape(-1)

# %% [markdown]
# # Model
#
# #### After testing multiple models from sklearn, ensemble methods were the ones that worked the best
#
# #### We are going to investigate Neural networks later

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
X_train, X_val, y_train, y_val = train_test_split( X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# defining parameter range 
# Number of trees in random forest
n_estimators = [200]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x*10) for x in range(1,5)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
njobs=[-1]
# Create the random grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
              'n_jobs' : njobs
                }
   
#grid = RandomizedSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 10) 
   
# fitting the model for grid search 
#grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
#print(grid.best_params_) 
#grid_predictions = grid.predict(X_val)

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
# Scaler not necessary here but it make it easier to change model, when we have to use it
pipe = Pipeline([('scaler', StandardScaler()), ('RandomForestRegressor', RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_split=2,max_features='auto',min_samples_leaf=2,bootstrap=True,max_depth=40))])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_val)
print('score', pipe.score(X_val,y_val))
print('validation mean abs error',mean_absolute_error(y_val, y_pred))
print('validation RMSE',mean_squared_error(y_val, y_pred,squared=False))
# Out:
# score 0.7342765675856777
# validation mean abs error 3.387712843588438
# validation RMSE 5.334443859859901

# %%
dataTransformer = DataTransformer(df_positions_test,df_education_test,df_seniority_test)
test_data =dataTransformer.transform(fit=False,labels=False,remove_info=False)
# Out:
# changing dates and text format
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# completing position end dates...
# added 64030 values
#
# completing education end dates...
# added 5715 values
#
# completing education start dates...
# average length:  3.6164438974724713 yrs
# added 879 values
#
# completing position end dates...
# average length:  3.973643719107162 yrs
# added 24 values
#
# completing education remaining dates...
# average start date:  2003.295803705871 yrs
# average end date:  2006.9122476033924 yrs
# added 18144 values
#
# completing position remaining dates...
# average start date:  2010.1666330822677 yrs
# average end date:  2014.140276800845 yrs
# added 6696 values
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\nguye\anaconda3\envs\envTF\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
X_test=np.asarray(test_data[feature_cols].values.tolist())
# matrix dim for emsemble method
X_test=np.reshape(X_test, (len(X_test), X_test.shape[1]*X_test.shape[2]))
y_pred = pipe.predict(X_test)

# %%
len(y_pred)
# Out:
# 66069

# %%
test_data['label'] = y_pred
test_data['true_or_predicted']=False

train_data['true_or_predicted']=True

df_all=pd.concat([train_data, test_data], axis=0)

now = datetime.now()
today=now.year+now.month/13

df_all['age']=(today-df_all['label']).astype(int)
df_all=df_all[['age','true_or_predicted']]
df_all.reset_index(inplace=True)

# %%
tamere=df_all[~df_all['true_or_predicted']]
tamere.reset_index(drop=True)
tamere
# Out:
#                                                  user_id  age  \
# 33931  ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...   92
# 33932  ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...   59
# 33933  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...   29
# 33934  ++7kB6m0hI1TgAPmyY1X6A5+2cvffV/mNepQVJd0smgtpB...   39
# 33935  ++9DtAOTiRRvECoMIpKbmg4ZM3TcQvn1bQ/jHgHWG0kf/b...   38
# ...                                                  ...  ...
# 99995  zzZdW3VGODRxRl2025ZR2w5+2cvffV/mNepQVJd0smgtpB...   36
# 99996  zzrNxfUzwZXNkSs15haLyA4ZM3TcQvn1bQ/jHgHWG0kf/b...   57
# 99997  zzrbQXjc2yHwbWjtQ9F3mg5+2cvffV/mNepQVJd0smgtpB...   32
# 99998  zzuZVPanBvW09lNk1C3h+Q5+2cvffV/mNepQVJd0smgtpB...   31
# 99999  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...   28
#
#        true_or_predicted
# 33931              False
# 33932              False
# 33933              False
# 33934              False
# 33935              False
# ...                  ...
# 99995              False
# 99996              False
# 99997              False
# 99998              False
# 99999              False
#
# [66069 rows x 3 columns]

# %%
for i in range (33931,33931+5):
    user=tamere.loc[i,'user_id']
    get_user_history(user)
    print('=========')
# Out:
#       major   startdate     enddate
# 99508    BS  1949-01-01  1953-01-01
#                                 jobtitle   startdate enddate
# 41525  former_owner_presently_consultant  1953-01-01     NaN
#                                 jobtitle  seniority
# 90141  former_owner_presently_consultant   7.064817
# =========
#                    major   startdate     enddate
# 92083  BS in Electronics  1973-01-01  1978-01-01
# 92505                NaN  1984-01-01  1987-01-01
#                                                  jobtitle   startdate  \
# 9781                    owner_|_computer_network_security  1993-06-01
# 106525  design_engineer_|_mechanical_industrial_engine...  1984-10-01
#
#            enddate
# 9781           NaN
# 106525  1989-05-01
#                                                  jobtitle  seniority
# 71129   design_engineer_|_mechanical_industrial_engine...   3.331507
# 222292                  owner_|_computer_network_security   7.334247
# =========
#                       major   startdate     enddate
# 133238  Master Grande Ecole  2013-01-01  2016-01-01
#                                                  jobtitle   startdate  \
# 228241  digital_communication_press_relations_|_cosmetics  2016-07-01
# 228215             assistant_business_development_manager  2014-06-01
# 176460  trainee_digital_brand_commerce_crm_implementat...  2018-04-01
# 237149  trainee_digital_brand_commerce_digital_plannin...  2017-09-01
# 200727  sales_business_development_executive_|_events_...  2017-06-01
# 30076                     event_promoter_public_relations  2015-07-01
# 220136  trainee_digital_brand_commerce_membership_prog...  2018-09-01
# 23563          freelance_author_lucifer_manga_books_serie  2016-12-01
# 213101  digital_communication_social_medias_activation...  2016-11-01
#
#            enddate
# 228241  2016-10-01
# 228215  2014-08-01
# 176460         NaN
# 237149  2018-03-01
# 200727  2017-08-01
# 30076   2015-08-01
# 220136         NaN
# 23563   2017-08-01
# 213101  2017-05-01
#                                                  jobtitle  seniority
# 399946  digital_communication_social_medias_activation...   4.307247
# 220871                    event_promoter_public_relations   1.908356
# 351436  trainee_digital_brand_commerce_membership_prog...   4.307247
# 354892  trainee_digital_brand_commerce_digital_plannin...   4.307247
# 111281  sales_business_development_executive_|_events_...   3.439384
# 44321          freelance_author_lucifer_manga_books_serie   4.020771
# 333670  digital_communication_press_relations_|_cosmetics   4.307247
# 24521              assistant_business_development_manager   3.787412
# 372408  trainee_digital_brand_commerce_crm_implementat...   4.307247
# =========
#                   major   startdate     enddate
# 106134  Master's Degree  2008-01-01         NaN
# 106774              NaN  2012-01-01  2013-01-01
# 106190               BS  1996-01-01  1997-01-01
#                                                  jobtitle   startdate  \
# 311981                                           director  2012-08-01
# 324558                                  preschool_teacher  2011-06-01
# 280513            sr_research_associate_|_pharmaceuticals  1999-09-01
# 320187           validation_scientist_|_computer_software  2014-09-01
# 72818                           clinical_data_coordinator  2004-09-01
# 245906   computational_chemistry_intern_|_pharmaceuticals  1997-12-01
# 330491                                 substitute_teacher  2011-01-01
# 288582  validation_scientist_bristol_myers_squibb_co_|...  2005-05-01
# 351507           validation_scientist_|_computer_software  2008-03-01
#
#            enddate
# 311981  2014-02-01
# 324558  2012-08-01
# 280513  2003-12-01
# 320187         NaN
# 72818   2005-05-01
# 245906  1998-12-01
# 330491  2011-05-01
# 288582  2007-09-01
# 351507  2012-12-01
#                                                  jobtitle  seniority
# 385257   computational_chemistry_intern_|_pharmaceuticals   4.142466
# 343977  validation_scientist_bristol_myers_squibb_co_|...   2.750685
# 20790                           clinical_data_coordinator   3.610914
# 375097           validation_scientist_|_computer_software   4.713699
# 231173            sr_research_associate_|_pharmaceuticals   5.046575
# 248331                                           director   7.421538
# 11467                                  substitute_teacher   2.039746
# 343355                                  preschool_teacher   2.855363
# =========
#          major   startdate     enddate
# 29395  B. Tech  2002-01-01  2006-01-01
# 29488      MSc  2009-01-01  2010-01-01
#                                                 jobtitle   startdate  \
# 149353                      business_development_manager  2007-01-01
# 163857  business_development_manager_|_computer_software  2007-07-01
# 136336          post_graduate_student_|_higher_education  2009-01-01
#
#            enddate
# 149353  2007-07-01
# 163857  2008-12-01
# 136336         NaN
#                                                 jobtitle  seniority
# 411244                      business_development_manager   5.325018
# 251617  business_development_manager_|_computer_software   5.002740
# 25815           post_graduate_student_|_higher_education   3.793151
# =========

# %% [markdown]
# ## RNN and perception with Tensorflow

# %%
# Import modules
from __future__ import print_function
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

import numpy as np
from numpy.random import shuffle
import time
import matplotlib.pyplot as plt

# Plot configurations
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
print(tf.__version__)

# %%
X_train.shape

# %%
X_val.shape

# %%
#keeping the same split for consistency

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

X_train=np.reshape(X_train, (len(X_train),original_shape[1],original_shape[2]))
X_train=np.swapaxes(X_train,1,2)
X_val=scaler.transform(X_val) # no fit
X_val=np.reshape(X_val, (len(X_val),original_shape[1],original_shape[2]))
X_val=np.swapaxes(X_val,1,2)
X_val.shape

# %%
label_scaler=StandardScaler()
y_train=label_scaler.fit_transform(y_train.reshape(-1, 1)).reshape(-1)
y_val=label_scaler.transform(y_val.reshape(-1, 1)).reshape(-1)

# %%
X_train[0]

# %%
from tensorflow.keras import layers
model = tf.keras.Sequential() 
model.add(layers.Input((original_shape[2],original_shape[1])))
model.add(layers.LSTM(1024, return_sequences=True))
model.add(layers.LSTM(256, input_shape=X.shape, return_sequences=False))
model.add(layers.Dense(32,activation='relu'))
model.add(layers.Dense(1))

print(model.summary() )
model.compile(loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0003),
              metrics=['accuracy']) 
history_LSTM = model.fit(X_train, y_train, validation_data=(X_val, y_val),batch_size=128, epochs=100)

# %%
y_pred2 = model.predict(X_val)
y_pred2 =label_scaler.inverse_transform(y_pred2.reshape(-1,1)).reshape(-1)
y_true =label_scaler.inverse_transform(y_val.reshape(-1,1)).reshape(-1)
accs=[abs(y_pred2[i]-y_true[i]) for i in range(len(y_true))]
sum(accs)/len(accs)
print('RMSE',mean_squared_error(y_true, y_pred,squared=False))

# %%
X_train=np.reshape(X_train, (len(X_train),original_shape[1]*original_shape[2]))
X_val=np.reshape(X_val, (len(X_val),original_shape[1]*original_shape[2]))
X_train.shape

# %%
y_val

# %%
from tensorflow.keras import layers
model_perceptron = tf.keras.Sequential() 
model_perceptron.add(layers.Input((original_shape[1]*original_shape[2])))
model_perceptron.add(layers.Dense(30,activation='relu',kernel_regularizer=tf.keras.regularizers.L1(0.001)))
model_perceptron.add(layers.Dense(20,activation='relu',kernel_regularizer=tf.keras.regularizers.L1(0.001)))
model_perceptron.add(layers.Dense(10,activation='relu'))
model_perceptron.add(layers.Dense(5,activation='relu'))
model_perceptron.add(layers.Dense(5,activation='relu'))
model_perceptron.add(layers.Dense(10,activation='relu',kernel_regularizer=tf.keras.regularizers.L1(0.001)))
model_perceptron.add(layers.Dense(1))

print(model_perceptron.summary() )
model_perceptron.compile(loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.001),
              metrics=['accuracy']) 
history_perceptron = model_perceptron.fit(X_train, y_train, validation_data=(X_val, y_val),batch_size=128, epochs=100)

# %%
y_val =label_scaler.inverse_transform(y_val.reshape(-1,1)).reshape(-1)

# %%
y_pred3 = model_perceptron.predict(X_val)
print(y_pred3.shape)
y_pred3 =label_scaler.inverse_transform(y_pred3.reshape(-1,1)).reshape(-1)

accs=[abs(y_pred3[i]-y_val[i]) for i in range(len(y_val))]
print('avg abs err:',sum(accs)/len(accs))
print('RMSE',mean_squared_error(y_val, y_pred3,squared=False))

# %% [markdown]
# # Prediction on all the data set

# %% [markdown]
# # Explaination end

# %%
#Usefull functions


def to_lower_case(df,col):
    df[col] =  df[col].str.lower()
    return df 
def to_datetime(df,col):
    df[col] =  pd.to_datetime(df[col], format='%Y-%m-%d')
    df[col] =  df[col].dt.year+ df[col].dt.month/13
    return df

print('changing dates and text format \n')

df_education = df_education.pipe(to_lower_case, col='major').pipe(to_datetime,col='startdate').pipe(to_datetime,col='enddate')
df_positions = df_positions.pipe(to_lower_case, col='jobtitle').pipe(to_datetime,col='startdate').pipe(to_datetime,col='enddate')
df_seniority = df_seniority.pipe(to_lower_case, col='jobtitle')

# %%
#filling missing values

def fill_end_dates(df):
    now = datetime.now()
    today=now.year+now.month/13
    #print('today',today)
    before=df['enddate'].isna().sum()
    df['enddate']=df.apply(lambda row: today if pd.isnull(row['enddate']) and (not pd.isnull(row['startdate'])) else row['enddate'],axis=1)
    print('added',before-df['enddate'].isna().sum(),'values \n')
    return df

print('completing position end dates...')

df_positions=fill_end_dates(df_positions)
print('completing education end dates...')
df_education=fill_end_dates(df_education)

# %%
def fill_startdate(df):
    df_nona=df[['startdate','enddate']].dropna(how='all',inplace=False)
    df_nona['length']=df_nona['enddate']-df_nona['startdate']
    avg_length=df_nona["length"].mean()
    print('average length: ',avg_length,'yrs')
    before=df['startdate'].isna().sum()
    df['startdate'].fillna(df['enddate']-avg_length, inplace=True)
    print('added',before-df['startdate'].isna().sum(),'values \n')
    return df
print('completing education start dates...')
df_education=fill_startdate(df_education)
print('completing position end dates...')
df_positions=fill_startdate(df_positions)

# %%
def fill_dates_missingall(df):
    df_nona=df[['startdate','enddate']].dropna(how='all',inplace=False)
    #df_nona['length']=df_nona['enddate']-df_nona['startdate']
    avg_start=df_nona["startdate"].mean()
    avg_end=df_nona["enddate"].mean()
    print('average start date: ',avg_start,'yrs')
    print('average end date: ',avg_end,'yrs')
    before=df['startdate'].isna().sum()
    df['startdate'].fillna(avg_start, inplace=True)
    df['enddate'].fillna(avg_end, inplace=True)
    print('added',before-df['startdate'].isna().sum(),'values \n')
    return df  
print('completing education remaining dates...')
df_education=fill_dates_missingall(df_education)
print('completing position remaining dates...')
df_positions=fill_dates_missingall(df_positions)

# %%
# filling missing education and positions
df_positions['jobtitle'].fillna('positions', inplace=True)
df_seniority['jobtitle'].fillna('positions', inplace=True)
df_education['major'].fillna('education', inplace=True)

# %%
df_seniority['seniority'].fillna((df_seniority['seniority'].mean()), inplace=True)

# %%
# sorting by startdate for later:
df_positions.sort_values(by=['startdate'],inplace=True)
df_education.sort_values(by=['startdate'],inplace=True)

# %%
print(df_education.isna().sum())
print(df_seniority.isna().sum())
df_positions.isna().sum()

# %%
df=df_positions.merge(df_seniority, how='right',left_on=['user_id','jobtitle'], right_on=['user_id','jobtitle']) # only position lacks users, hence right join
df=df.groupby('user_id').agg(lambda x: list(x))
df_education_temp=df_education.groupby('user_id').agg(lambda x: list(x))
df=df.merge(df_education_temp, how='outer', left_on='user_id', right_on='user_id')
len(df)

# %%
test_id ='++NWXZ8bW3I7VaXV77eiwA5+2cvffV/mNepQVJd0smgtpBr4MGMFJQ=='
print(test_id)
get_user_history(test_id)

# %%
missing_count={'jobtitle': 0,'startdate_x':0,'enddate_x':0,'startdate_y':0,'startdate_y':0,'major':0,'seniority':0}
mask=[]

for rowIndex, row in df.iterrows(): 
    ismissing=False
    for i, value in row.items():
        for n in value:
            if (pd.isnull(n)):
                ismissing=True
                missing_count[i]=missing_count[i]+1
    if ismissing:
        mask.append(True)
    else:
        mask.append(False)
missing_count

# %%
len([x for x in mask if x])

# %%
df

# %%
df['startdate_x']=df.apply(lambda row: [max(row['enddate_y']) if pd.isnull(date) else date for date in row['startdate_x'] ] ,axis=1)
now = datetime.now()
today=now.year+now.month/13
df['enddate_x']=df['enddate_x'].apply(lambda dates: [today if pd.isnull(date) else date for date in dates])
