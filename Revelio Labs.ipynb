# %% [markdown]
# ### Loading the data

# %%
import os
import urllib.request
import pandas as pd

# %% [markdown]
# Downloading the data, so that we don't have to do it again if we restart the kernel

# %%
urls=["https://info0.s3.us-east-2.amazonaws.com/recruitment/positions.csv","https://info0.s3.us-east-2.amazonaws.com/recruitment/education.csv","https://info0.s3.us-east-2.amazonaws.com/recruitment/jobtitle_seniority.csv"]

# data folder, create if it does not exists
os.makedirs('./data/', exist_ok=True) 
    
# if .csv file does not exists, download it
for url in urls:
    path='./data/' + os.path.basename(url)
    if not os.path.exists(path):
        urllib.request.urlretrieve(url, path)
        
print('data downloaded')
# Out:
# data downloaded

# %% [markdown]
# Load the data into pandas data frames

# %%
#TODO dl?
#TODO S3 bucket code?
df_positions = pd.read_csv("./data/positions.csv")
df_education = pd.read_csv("./data/education.csv")
df_seniority = pd.read_csv("./data/jobtitle_seniority.csv")

# %% [markdown]
# #### Checking the data

# %%
df_positions=df_positions.sort_values(by=['user_id'])
df_positions.tail(30)
# Out:
#                                                   user_id  \
# 290927  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 302969  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 185704  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 260036  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 185533  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 260214  zzP7zTK3JaSeTqz9AtikLg5+2cvffV/mNepQVJd0smgtpB...
# 224320  zzVjGj6yusqUwYDuy+sXmg4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 217504  zzVjGj6yusqUwYDuy+sXmg4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 38826   zzVjGj6yusqUwYDuy+sXmg4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 321986  zzZdW3VGODRxRl2025ZR2w5+2cvffV/mNepQVJd0smgtpB...
# 250730  zzZdW3VGODRxRl2025ZR2w5+2cvffV/mNepQVJd0smgtpB...
# 292998  zzZdW3VGODRxRl2025ZR2w5+2cvffV/mNepQVJd0smgtpB...
# 15925   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 20394   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 146865  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 19547   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 136212  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 156930  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 138385  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 161624  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 162425  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 15089   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 146169  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 15923   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 20486   zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
# 309939  zzrNxfUzwZXNkSs15haLyA4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 338504  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 334912  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 359048  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 248375  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
#
#                                                  jobtitle   startdate  \
# 290927                 human_resource_intern_|_automotive  2015-01-01
# 302969  research_participate_intern_|_government_admin...  2016-08-01
# 185704                     team_member_|_higher_education  2016-01-01
# 260036              research_assistant_|_higher_education  2015-03-01
# 185533      manufacturing_engineering_intern_|_automotive  2014-07-01
# 260214                        control_engineer_simulation  2018-07-01
# 224320                        assistant_district_attorney  1975-11-01
# 217504              lieutenant_corps_engineers_|_military  1966-08-01
# 38826                                     sole_practioner  1973-10-01
# 321986             gerente_de_marketing_adulto_trabajador  2004-08-01
# 250730  coordinador_nacional_de_universidad_en_linea_cnci  2010-02-01
# 292998                                  gerente_de_ventas  2011-05-01
# 15925                                 battalion_commander  2010-09-01
# 20394                  senior_engineer_operations_officer  2005-07-01
# 146865           platoon_leader_company_executive_officer  1995-01-01
# 19547               battalion_executive_officer_battalion  2006-07-01
# 136212                      operations_officer_|_military  2013-07-01
# 156930                 secretary_general_staff_|_military  2008-09-01
# 138385                        commander_district_engineer  2015-07-01
# 161624                                  division_engineer  2012-04-01
# 162425                     student_senior_service_college  2012-08-01
# 15089                       command_general_staff_college  2004-07-01
# 146169             engineer_company_brigade_staff_trainer  2002-04-01
# 15923                            student_engineer_officer  1998-01-01
# 20486     company_commander_battalion_battalion_assistant  1998-11-01
# 309939  partner_head_private_client_department_|_law_p...  1992-01-01
# 338504                  coordinador_de_personal_embarcado  2017-12-01
# 334912                  operador_|_logistics_supply_chain  2014-11-01
# 359048                  supervisor_de_personal_|_maritime  2016-05-01
# 248375    supervisor_de_personal_|_logistics_supply_chain  2015-11-01
#
#            enddate
# 290927  2015-02-01
# 302969  2017-02-01
# 185704  2016-12-01
# 260036  2015-05-01
# 185533  2014-08-01
# 260214         NaN
# 224320  1997-03-01
# 217504  1968-05-01
# 38826   1975-11-01
# 321986  2009-08-01
# 250730  2011-05-01
# 292998         NaN
# 15925   2012-04-01
# 20394   2006-06-01
# 146865  1997-12-01
# 19547   2008-09-01
# 136212  2015-06-01
# 156930  2010-08-01
# 138385         NaN
# 161624  2012-07-01
# 162425  2013-06-01
# 15089   2005-06-01
# 146169  2004-06-01
# 15923   1998-10-01
# 20486   2002-03-01
# 309939         NaN
# 338504         NaN
# 334912  2015-09-01
# 359048  2017-09-01
# 248375  2016-05-01

# %% [markdown]
# #### Looking at the dates, linkedIn only has the year and month information, so date formatting is YYYY-MM-DD
# #### Position titles and fields are seperated by '\_|\_', words are seperated by '_'

# %%
df_education=df_education.sort_values(by=['user_id'])
df_education.head()
# Out:
#                                                   user_id  \
# 99508   ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92083   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92505   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 133238  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
# 5126    ++6zEVtPCi83vpPTHSY2Vg5+2cvffV/mNepQVJd0smgtpB...
#
#                                    major   startdate     enddate
# 99508                                 BS  1949-01-01  1953-01-01
# 92083                  BS in Electronics  1973-01-01  1978-01-01
# 92505                                NaN  1984-01-01  1987-01-01
# 133238               Master Grande Ecole  2013-01-01  2016-01-01
# 5126    Bachelor of Science (B.Sc.) (ED)  2001-01-01  2006-01-01

# %%
df_seniority=df_seniority.sort_values(by=['user_id'])
df_seniority.head()
# Out:
#                                                   user_id  \
# 90141   ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 71129   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 222292  ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 399946  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
# 220871  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
#
#                                                  jobtitle  seniority
# 90141                   former_owner_presently_consultant   7.064817
# 71129   design_engineer_|_mechanical_industrial_engine...   3.331507
# 222292                  owner_|_computer_network_security   7.334247
# 399946  digital_communication_social_medias_activation...   4.307247
# 220871                    event_promoter_public_relations   1.908356

# %%
#Missing values
print(df_positions.isna().sum(),'------',sep='\n')
print(df_education.isna().sum(),'------',sep='\n')
print(df_seniority.isna().sum(),'------',sep='\n')
# Out:
# user_id           0
# jobtitle       1449
# startdate      9059
# enddate      107231
# dtype: int64
# ------
# user_id          0
# major        63838
# startdate    28628
# enddate      35526
# dtype: int64
# ------
# user_id         0
# jobtitle     2005
# seniority       0
# dtype: int64
# ------

# %%
df_education[  df_education['major'].str.contains("Bachelor", na=False)]
# Out:
#                                                   user_id  \
# 5126    ++6zEVtPCi83vpPTHSY2Vg5+2cvffV/mNepQVJd0smgtpB...
# 89122   ++8qqHNDQSyp1Yd45ROBZg5+2cvffV/mNepQVJd0smgtpB...
# 226159  ++P3GpkLINRrbYEiFplujg5+2cvffV/mNepQVJd0smgtpB...
# 225489  ++P3GpkLINRrbYEiFplujg5+2cvffV/mNepQVJd0smgtpB...
# 67425   ++QrpNyfgK5vmh9A9q+J9Q5+2cvffV/mNepQVJd0smgtpB...
# ...                                                   ...
# 177381  zz3kcoewShXY94zbqfJyrA5+2cvffV/mNepQVJd0smgtpB...
# 106192  zzCRAAzCyXOiz/bYdL3tdQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 51195   zzHd7Vh3UUHEOpzT/0N5dg5+2cvffV/mNepQVJd0smgtpB...
# 34319   zzMISXlfrn0Fw/rOs6RlbQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 185119  zzdHAVxl9iQrwom22S/FLg5+2cvffV/mNepQVJd0smgtpB...
#
#                                          major   startdate     enddate
# 5126          Bachelor of Science (B.Sc.) (ED)  2001-01-01  2006-01-01
# 89122                            Bachelor (BA)  2004-01-01  2006-01-01
# 226159  Bachelor's degree Major in Accountancy  2002-01-01  2004-01-01
# 225489        Bachelor's degree in Accountancy  2000-01-01  2002-01-01
# 67425              Bachelor of Science (B.Sc.)  2007-01-01  2011-01-01
# ...                                        ...         ...         ...
# 177381                 Bachelor of Arts (B.A.)  1992-01-01  1996-01-01
# 106192                 Bachelor of Arts (B.A.)  1994-01-01  1998-12-31
# 51195           Bachelor of Engineering (B.E.)  2008-01-01  2012-01-01
# 34319                        Bachelor's degree  2003-01-01  2007-01-01
# 185119                       Bachelor's Degree  1990-01-01  1994-01-01
#
# [38220 rows x 4 columns]

# %%
## Data cleaning remove nans

# %% [markdown]
# #### As expected a person can have multiple education, and position entries

# %%
#Usefull functions
#https://www.geeksforgeeks.org/create-a-pipeline-in-pandas/
def to_lower_case(df,col):
    df[col] =  df[col].str.lower()
    return df 
def to_datetime(df,col):
    df[col] =  pd.to_datetime(df[col], format='%Y-%m-%d')
    return df

# %%
pipeline = df_education.pipe(to_lower_case, col='major').pipe(to_datetime,col='startdate').pipe(to_datetime,col='enddate')

# %%
pipeline
# Out:
#                                                   user_id  \
# 99508   ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92083   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 92505   ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 133238  ++6+hv3i5RAVsrWO8q5JEQ5+2cvffV/mNepQVJd0smgtpB...
# 5126    ++6zEVtPCi83vpPTHSY2Vg5+2cvffV/mNepQVJd0smgtpB...
# ...                                                   ...
# 156507  zzrNxfUzwZXNkSs15haLyA4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 156315  zzrNxfUzwZXNkSs15haLyA4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 184597  zzrbQXjc2yHwbWjtQ9F3mg5+2cvffV/mNepQVJd0smgtpB...
# 52175   zzuZVPanBvW09lNk1C3h+Q5+2cvffV/mNepQVJd0smgtpB...
# 169422  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
#
#                                                     major  startdate  \
# 99508                                                  bs 1949-01-01
# 92083                                   bs in electronics 1973-01-01
# 92505                                                 NaN 1984-01-01
# 133238                                master grande ecole 2013-01-01
# 5126                     bachelor of science (b.sc.) (ed) 2001-01-01
# ...                                                   ...        ...
# 156507                                            llb law 1982-01-01
# 156315                                                NaN 1980-01-01
# 184597                                          bachiller 2008-01-01
# 52175                        doctor of philosophy (ph.d.) 2010-01-01
# 169422  gestión de recursos humanos/administración de ... 2017-01-01
#
#           enddate
# 99508  1953-01-01
# 92083  1978-01-01
# 92505  1987-01-01
# 133238 2016-01-01
# 5126   2006-01-01
# ...           ...
# 156507 1985-01-01
# 156315 1982-01-01
# 184597 2012-01-01
# 52175  2014-01-01
# 169422 2021-01-01
#
# [226184 rows x 4 columns]

# %%
test_id =df_education.iat[2,0]
def get_user_history(user_id):
    print(df_education[df_education['user_id'].str.contains(user_id,regex=False,na=False)][['major', 'startdate','enddate']])
    print(df_positions[df_positions['user_id'].str.contains(user_id,regex=False,na=False)][['jobtitle', 'startdate','enddate']])
    print(df_seniority[df_seniority['user_id'].str.contains(user_id,regex=False,na=False)][['jobtitle', 'seniority']])
get_user_history(test_id)
# Out:
#                    major  startdate    enddate
# 92083  bs in electronics 1973-01-01 1978-01-01
# 92505                NaN 1984-01-01 1987-01-01
#                                                  jobtitle   startdate  \
# 9781                    owner_|_computer_network_security  1993-06-01
# 106525  design_engineer_|_mechanical_industrial_engine...  1984-10-01
#
#            enddate
# 9781           NaN
# 106525  1989-05-01
#                                                  jobtitle  seniority
# 71129   design_engineer_|_mechanical_industrial_engine...   3.331507
# 222292                  owner_|_computer_network_security   7.334247

# %%
test_id

# %%
user_dic={}
def user_id_to_id(user_id):
    if not user_id in user_dic:
        user_dic[user_id]=len(user_dic)
    return user_dic[user_id]

#for index, row in df_positions.iterrows():
#    row['id']=user_id_to_id(row['user_id'])

# %%
df.merge(df

# %%
df=df_positions.merge(df_education, left_on='user_id', right_on='user_id').merge(df_seniority, left_on='user_id', right_on='user_id')

# %%
df
# Out:
#                                                    user_id  \
# 0        ++5SW5MI5/h8X1hMA3QnmQ4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 1        ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 2        ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 3        ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# 4        ++5qk2+uEmkI/3Z4FrBwDw4ZM3TcQvn1bQ/jHgHWG0kf/b...
# ...                                                    ...
# 6698663  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 6698664  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 6698665  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 6698666  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
# 6698667  zzvZxBSf81furoFl3PcSuHAG1BvSkUYANepQVJd0smgtpB...
#
#                                               jobtitle_x startdate_x  \
# 0                      former_owner_presently_consultant  1953-01-01
# 1                      owner_|_computer_network_security  1993-06-01
# 2                      owner_|_computer_network_security  1993-06-01
# 3                      owner_|_computer_network_security  1993-06-01
# 4                      owner_|_computer_network_security  1993-06-01
# ...                                                  ...         ...
# 6698663                supervisor_de_personal_|_maritime  2016-05-01
# 6698664  supervisor_de_personal_|_logistics_supply_chain  2015-11-01
# 6698665  supervisor_de_personal_|_logistics_supply_chain  2015-11-01
# 6698666  supervisor_de_personal_|_logistics_supply_chain  2015-11-01
# 6698667  supervisor_de_personal_|_logistics_supply_chain  2015-11-01
#
#           enddate_x                                              major  \
# 0               NaN                                                 bs
# 1               NaN                                  bs in electronics
# 2               NaN                                  bs in electronics
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 6698663  2017-09-01  gestión de recursos humanos/administración de ...
# 6698664  2016-05-01  gestión de recursos humanos/administración de ...
# 6698665  2016-05-01  gestión de recursos humanos/administración de ...
# 6698666  2016-05-01  gestión de recursos humanos/administración de ...
# 6698667  2016-05-01  gestión de recursos humanos/administración de ...
#
#         startdate_y  enddate_y  \
# 0        1949-01-01 1953-01-01
# 1        1973-01-01 1978-01-01
# 2        1973-01-01 1978-01-01
# 3        1984-01-01 1987-01-01
# 4        1984-01-01 1987-01-01
# ...             ...        ...
# 6698663  2017-01-01 2021-01-01
# 6698664  2017-01-01 2021-01-01
# 6698665  2017-01-01 2021-01-01
# 6698666  2017-01-01 2021-01-01
# 6698667  2017-01-01 2021-01-01
#
#                                                 jobtitle_y  seniority
# 0                        former_owner_presently_consultant   7.064817
# 1        design_engineer_|_mechanical_industrial_engine...   3.331507
# 2                        owner_|_computer_network_security   7.334247
# 3        design_engineer_|_mechanical_industrial_engine...   3.331507
# 4                        owner_|_computer_network_security   7.334247
# ...                                                    ...        ...
# 6698663    supervisor_de_personal_|_logistics_supply_chain   3.753425
# 6698664                  supervisor_de_personal_|_maritime   3.835616
# 6698665                  coordinador_de_personal_embarcado   2.777727
# 6698666                  operador_|_logistics_supply_chain   2.879473
# 6698667    supervisor_de_personal_|_logistics_supply_chain   3.753425
#
# [6698668 rows x 9 columns]

# %% [markdown]
# ## Choosing the training Data
#
# People with highscool information have ages that are easy to predict since most people end highschool at the same age.
# The same is true for Bachelors.
# As a general rule, the ealier the education is in terms of degree, the better it is to predict the age because of the smaller variability.
